# %%
import os
import json
from langsmith import Client, traceable
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langsmith.evaluation import evaluate
from dotenv import load_dotenv

# Load environment variables
load_dotenv(override=True)

# Initialize LangSmith client
client = Client()

# Define the evaluation target
@traceable
def evaluate_sectionizer(input_data):
    messages = [
        {
            "role": "system",
            "content": """You are tasked with evaluating a submission based on the provided original file text and the assigned sectionizer type. You will also receive the first 500 characters of each section generated by the submission. Your evaluation involves two tasks:

Task 1: Validate Sectionizer Type
• Objective: Determine if the assigned sectionizer type is correct for the given file.
• Possible Types:
  • NOT_RELATED_TOPICS: The document contains multiple unrelated topics, often seen in meeting minutes with varied agenda items.
  • RELATED_TOPICS: The document revolves around a single main topic, possibly with several subtopics related to that central theme.
  • OTHER: The document requires further analysis or pertains to a topic that cannot be extracted from text alone (e.g., election results).
• Output: Provide a boolean (True/False) indicating whether the sectionizer type is correct, along with a brief justification for your decision.

Task 2: Evaluate Document Splitting
• Objective: Verify if the document was split correctly based on the assigned sectionizer type.
• Criteria:
  • The document should only be split into multiple sections if the sectionizer type is NOT_RELATED_TOPICS.
  • Evaluate the logical placement of the splits, if applicable.
• Output: Confirm whether the document was split correctly (True/False) and provide a brief explanation.

Respond with a JSON object containing the following keys:

    "sectionizer_type_correct": boolean,
    "sectionizer_type_justification": "string",
    "splitting_correct": boolean,
    "splitting_explanation": "string"
""",
        },
        {"role": "user", "content": f"Original File Text and sectionizer type:\n\n{input_data['input']}\n\nGenerated Sections (First 500 Characters Each):\n\n{input_data['submission']}"},
    ]
    chat_model = ChatOpenAI(model="gpt-4", temperature=0)
    result = chat_model.invoke(messages)
    print("\033[94m" + result.content + "\033[0m")
    return result.content


dataset_name = "neurapolis-file-sections"
# dataset = client.create_dataset(dataset_name=dataset_name)
# inputs, outputs = zip(*[(example[0], example[1]) for example in examples])
# client.create_examples(inputs=inputs, outputs=outputs, dataset_id=dataset.id)

# Define the evaluator
def correct_evaluation(run, example):
    # Print the input data for debugging
    print("Input data:")
    print(json.dumps(example.inputs, indent=2))
    
    # Print the run output for debugging
    print("\nRun output:")
    print(json.dumps(run.outputs, indent=2))
    run_output = run.outputs.get("sections")
    expected_output = example.outputs
    
    # Parse the JSON string in run_output
    run_output_dict = json.loads(run_output)
    
    # Compare each field
    sectionizer_type_correct = run_output_dict["sectionizer_type_correct"] == expected_output["sectionizer_type_correct"]
    splitting_correct = run_output_dict["splitting_correct"] == expected_output["splitting_correct"]
    
    # Calculate overall score
    score = (sectionizer_type_correct + splitting_correct) / 2
    
    return {"score": score, "key": "correct_evaluation"}

# Run the evaluation
results = evaluate(
    evaluate_sectionizer,
    data=dataset_name,
    evaluators=[correct_evaluation],
    experiment_prefix="Sectionizer Evaluation",
    description="Testing the sectionizer evaluation system.",
)

print(f"Evaluation results: {results}")

# Example of using a LangChain runnable
prompt = ChatPromptTemplate.from_messages([
    ("system", """You are tasked with evaluating a submission based on the provided original file text and the assigned sectionizer type. You will also receive the first 500 characters of each section generated by the submission. Your evaluation involves two tasks:

Task 1: Validate Sectionizer Type
• Objective: Determine if the assigned sectionizer type is correct for the given file.
• Possible Types:
  • NOT_RELATED_TOPICS: The document contains multiple unrelated topics, often seen in meeting minutes with varied agenda items.
  • RELATED_TOPICS: The document revolves around a single main topic, possibly with several subtopics related to that central theme.
  • OTHER: The document requires further analysis or pertains to a topic that cannot be extracted from text alone (e.g., election results).
• Output: Provide a boolean (True/False) indicating whether the sectionizer type is correct, along with a brief justification for your decision.

Task 2: Evaluate Document Splitting
• Objective: Verify if the document was split correctly based on the assigned sectionizer type.
• Criteria:
  • The document should only be split into multiple sections if the sectionizer type is NOT_RELATED_TOPICS.
  • Evaluate the logical placement of the splits, if applicable.
• Output: Confirm whether the document was split correctly (True/False) and provide a brief explanation.

Respond with a JSON object containing the following keys:

    "sectionizer_type_correct": boolean,
    "sectionizer_type_justification": "string",
    "splitting_correct": boolean,
    "splitting_explanation": "string"
"""),
    ("user", "Original File Text and sectionizer type:\n\n{input}\n\nGenerated Sections (First 500 Characters Each):\n\n{submission}")
])
chat_model = ChatOpenAI(model="gpt-4")
output_parser = StrOutputParser()

chain = prompt | chat_model | output_parser

# Evaluate the LangChain runnable
langchain_results = evaluate(
    chain.invoke,
    data=dataset_name,
    evaluators=[correct_evaluation],
    experiment_prefix="Sectionizer Evaluation LangChain",
)

print(f"LangChain evaluation results: {langchain_results}")
# Out:
# View the evaluation results for experiment: 'Sectionizer Evaluation-19674873' at:
# https://eu.smith.langchain.com/o/f2baf51a-5907-4625-b2ab-a98883dd8671/datasets/20233d7f-efe8-40b1-afbb-457beb5f271f/compare?selectedSessions=979899df-af92-44f9-abf2-775c999ae917
# 0it [00:00, ?it/s]Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run 397134b4-63c3-4b42-9077-fa7f59546c7a: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running target function: 'input'
# Error running target function: 'input'
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run 6de9ac81-0def-4da8-9f74-b56a05a88e96: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running target function: 'input'
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run 29c99693-d42a-4572-a547-aa15a47ba473: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running target function: 'input'
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run 3e3a2f67-39dd-4d60-a596-86631bebaadc: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running target function: 'input'
# Error running target function: 'input'
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run fac790c2-1e00-4815-8b58-4625555efd13: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running target function: 'input'
# Error running target function: 'input'
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run c8c09e55-2e84-40b2-b3f0-dd637e1e470f: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running target function: 'input'
# Error running target function: 'input'
# Error running target function: 'input'
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run 6c9f719c-e904-42ed-b34d-20f7bda1b23e: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running target function: 'input'
# Error running target function: 'input'
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run b385dce1-ec08-4727-ad10-fe9288cde4a3: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running target function: 'input'
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run f20fd30f-5b6d-4ce8-8f5c-22aa09ebbb23: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running target function: 'input'
# Error running target function: 'input'
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run 722310bc-ef06-45b7-8cdc-b85c7e342894: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running target function: 'input'
# Error running target function: 'input'
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run 99da2528-5d56-42a7-b978-f887581b27fe: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running target function: 'input'
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run 5860d386-2840-4660-ad60-4cf2d8b23e63: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run 972781bb-8aa6-4d6b-bc9d-f1db7ccc3502: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running target function: 'input'
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run 2fdb9182-b2d1-4f7c-9db6-e8caf7117f36: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run adf97332-739a-4c27-adca-c3557893d3f3: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run 9cbc5608-b066-4547-a942-7e7e5f7ee187: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run 497b6158-08bd-4465-84d4-c786b3587097: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run 4ebd08d0-af6c-40cc-be8b-93f99949942a: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run f53d4327-1854-4416-8109-bd915c4fe4f1: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run e7158304-0263-439c-9809-5475ca79c560: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run b9fded8a-993d-4255-9826-93b63a2cc4fa: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run 0230ba26-b596-4292-a8d1-c72e57671a78: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run 9cc92a93-be30-437d-aa8a-9159e8fbec5e: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run f9f2c1ec-7eaf-4273-9cc8-02781c28db57: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run e2736951-c2b4-45da-a956-2ee38460cb09: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run 8167a22a-9dfe-4726-9ad6-1170fce642e5: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run d6118102-4a87-4db4-9db8-d35a96db05fe: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run 070c910c-0ba0-4cc1-8871-6b703496bf03: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run ae6dee98-7db9-405a-84b0-d0d78f679387: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py", line 339, in loads
#     raise TypeError(f'the JSON object must be str, bytes or bytearray, '
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType
# Error running evaluator <DynamicRunEvaluator correct_evaluation> on run 00dc7d57-f738-4ac0-bcec-be3e2b745147: TypeError('the JSON object must be str, bytes or bytearray, not NoneType')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1323, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 629, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 626, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_75462/3628032440.py", line 73, in correct_evaluation
#     run_output_dict = json.loads(run_output)
#                       ^^^^^^^^^^^^^^^^^^^^^^
# ...
#   "sectionizer_type": "NOT_RELATED_TOPICS"
# }
#
# Run output:
# {
#   "output": null
# }
# Input data:
# {
#   "file": "\u00d6ffentliche Sitzung\n\ndes Ortschaftsrates Munzingen\n\nam 29.06.2022\n\nim B\u00fcrgersaal in Munzingen in Freiburg im Breisgau\n\nErgebnismitteilung\n\nOrtschaftsr\u00e4tinnen und Ortschaftsr\u00e4te mit Stimmrecht:\nAnwesend:\nOrtschaftsr\u00e4tinnen und Ortschaftsr\u00e4te mit Stimmrecht:\nOrtsvorsteher Christian Schildecker\nOrtschaftsr\u00e4tin Elisabetha Gr\u00e4fin von Kageneck\nOrtschaftsrat Klaus Riemann\nOrtschaftsrat Philipp Schillinger\nOrtschaftsrat Ulrich Schopp\nOrtschaftsr\u00e4tin Kunigunde Stifel\nOrtschaftsr\u00e4tin Katja Weber\nOrtschaftsr\u00e4tin Katharina Wirth\n\nEs fehlten:\nOrtschaftsrat Clemens Lang entschuldigt!\nOrtschaftsrat Toni Luhr unentschuldigt\nOrtschaftsr\u00e4tin Liliane Moser entschuldigt!\nOrtschaftsrat Wolfgang Schmid erkrankt!\n\nG\u00e4ste / Sachkundige und Sachverst\u00e4ndige:\nReferentin Frau Dr. Sandra Hook, Abteilungsleiterin des Umweltschutzamtes (UWSA) der Stadt Freiburg im Breisgau, Abteilung IV, Klimaschutz und Luftreinhaltung; Tel.: 0761/201-6140; E-Mail: Sandra.Hook@stadt.freiburg.de\n\nVon der Verwaltung: Beate Eicher, Schriftf\u00fchrerin\n\nBei Er\u00f6ffnung der regul\u00e4ren \u00f6ffentlichen Sitzung um 19:30 Uhr durch OV Schildecker war das Plenum beschlussf\u00e4hig. (Die Tagesordnung siehe Anlage 1).\n\nOV Schildecker begr\u00fc\u00dfte alle B\u00fcrgerinnen und B\u00fcrger.\n\n# TOP 1 Fragen und Anregungen aus der B\u00fcrgerschaft\nEin B\u00fcrger tat seine Meinung bezgl. der weiterf\u00fchrenden Schule am Tuniberg kund.\n\n# TOP 2 Kindertagesst\u00e4ttenbedarfsplanung 2022/2023\nBeschluss-Vorlage G-22/115, aber keine Anh\u00f6rung m\u00f6glich, sondern lediglich Info \u00fcber finalen Gemeinderatsbeschluss vom 28.06.2022, da Sitzungstermin seitens des Munzinger Ortschaftsrates wissentlich verschoben wurde.\n\n## Ergebnis des Gemeinderatsbeschlusses:\ndie Drucksache G-22/115 wurde gestern in der Gemeinderatssitzung einstimmig gem\u00e4\u00df Beschlussantrag der Drucksache beschlossen.\n\nVortrag: OV Schildecker f\u00fchrte kurz in diese Vorlage ein und informierte die R\u00e4te dar\u00fcber, dass der Gemeinderat die Drucksache einstimmig beschlossen hat.\n\nDie Munzinger Ratssitzung sei nach hinten verschoben worden, weil viele R\u00e4te zum urspr\u00fcnglich anberaumten Termin 22.06.2022 in Urlaub gewesen seien. Aufgrund dessen war eine formelle Anh\u00f6rung des OR Munzingens nicht mehr m\u00f6glich. OR Riemann r\u00fcgte dies als \u201epeinlich\u201c. Er gab zu bedenken, dass alle Ortschaftsr\u00e4t:innen eine Anwesenheitspflicht haben. Bei der Terminplanung der kommenden Sitzungsperiode muss hier eine bessere Abstimmung erfolgen. OV Schildecker stellte fest, dass es zuk\u00fcnftig keine Verschiebungen von Sitzungsterminen wegen urlaubsbedingter Abwesenheiten mehr geben wird.\n\nInhaltlich gebe es hier nicht viel Neues: Eine vorgesehene neue Kita in Munzingen h\u00e4nge weiterhin in der Warteschleife und problematisch sehe OR\u00e4tin Stifel, dass die Tuniberg-Ortschaften als Betreuungsverbund gesehen w\u00fcrden.\n\nAuf Anfrage von OR\u00e4tin Wirth antwortete OV Schildecker, dass der bisherige Tr\u00e4ger der Schulkindbetreuung, das Jugendhilfswerk Freiburg e.V. den Tr\u00e4gervertrag gek\u00fcndigt habe und ab kommendem Schuljahr die Stadt Freiburg die Tr\u00e4gerschaft an der Lindenbergschule \u00fcbernehme. Es wird h\u00e4nderingend und mit Hochdruck nach geeignetem Personal gesucht.\n\n## Wortmeldungen:\n- OR Riemann\n- OR\u00e4tin Stifel\n- OR\u00e4tin Wirth\n- OR\u00e4tin Weber\n\nProtokoll der OR-Sitzung vom 29.06.2022\n\n# TOP 3\n\n**Weiterf\u00fchrende Schule am Tuniberg (lt. Ank\u00fcndigung des OV bei Sitzung 05/2022)**\n\n**Vortrag:**\nOV Schildecker f\u00fchrte kurz in diese Thematik ein und erl\u00e4uterte, dass sich zuletzt die Tiengener und Waltershofener R\u00e4te dem Opfinger Vorsto\u00df angeschlossen h\u00e4tten, als weiterf\u00fchrende Schule am Tuniberg einen Verbund aus Gemeinschaftsschule und Gymnasium zu realisieren ...
#   "sectionizer_type": "NOT_RELATED_TOPICS"
# }
#
# Run output:
# {
#   "output": null
# }
# Input data:
# {
#   "file": "![Image](data:image/jpeg;base64,...\n\n# Realizing Progress\n\n## Tourismuskonzept Freiburg 2024: Wo wir aktuell stehen\n\n### Dez. 2022 \u2013 Febr. 2023\n- Dez. 22: AR-Auftrag zur Fortschreibung TK\n- Ende Dez. 22 \u2013 Febr. 23: Ausschreibung & Agenturauswahl (zusammen mit Steuerungsgruppe, gebildet aus Mitgliedern des Tourismusbeirats)\n\n### M\u00e4rz 2023\n- Interner Kick-off\n  - Vorgehen\n  - Timing\n  - Akteur*innen\n\n### April/Mai 2023\n- Desk Research\n- Pers\u00f6nliche Gespr\u00e4che\n- Online-Umfrage Bev\u00f6lkerung\n\n### April/Mai 2023\n- Wirtschaftsfaktor Tourismus\n- Zahlen, Daten, Fakten zu Angebot/Nachfrage\n- Quantitatives & qualitatives Benchmarking\n\n### Juni \u2013 Aug. 2023\n- 12.06. Team-Workshop\n- 15.06. Workshop Stadtverwaltung\n- 04.07. Steuerungsgruppensitzung\n- 25.07., 26.07., 02.08. Erarbeitungs-Workshops\n\n### Sept./Okt. 2023\n- 05.09. Steuerungsgruppensitzung\n  - Konkretisierung/Grobraster\n- 20.10. Steuerungsgruppensitzung\n\n### Beauftragung\n\n### Projekt-organisation\n\n### Analyse und Evaluierung\n\n### Erarbeitung und Abstimmung\n\n![Realizing Progress](https://example.com/image.jpg)\n\n# Rahmen zur Umsetzung der Schl\u00fcsselprojekte: Die \u00dcbernachtungssteuer.\n\n## Ab 2024: 1 Mio. Euro pro Jahr f\u00fcr die FWTM.\n\n![Realizing Progress](https://example.com/image0)\n\n# Notwendige Grundlagen FWTM-intern\n\n\u2022 01) Organisationsentwicklung der FWTM \u2192 Neuausrichtung und Priorisierung der Aufgabenbereiche, Anpassung Abteilungsstrukturen\n\n\u2022 02) Ausrichtung der Tourist Information \u2192 Einbindung in touristische Sparte der FWTM, Produktentwicklung, Daten-/Informationsmanagement\n\n\u2022 03) Neue Kennziffern und Messbarkeit \u2192 Kennziffern f\u00fcr Arbeit der FWTM/Umsetzung Tourismuskonzept/Marke, Entwicklung Dashboard\n\n![FREI \u2014/ 4](https://example.com/image2)\n\n![now](https://example.com/image6)\n\n![Realizing Progress](https://example.com/image.jpg)\n\n# Schl\u00fcsselprojekte Oberthema Freiburg- Gef\u00fchl mit den Unterthemen Kulinarik, Kultur, Workation\n\n- 04) Stadtteile/Ortschaften: Positionierung und Strukturierung\n- 05) Zielgruppen: Bereitstellung relevanter Informationen\n- 06) Begegnungsst\u00e4tten und Workation-Infrastruktur\n- 07) Markenkonforme Verbindung Altstadt \u2013 Stadtgarten\n- 08) Markenkonforme Verbindung Bahnhof \u2013 Altstadt\n- 09) Kulinarik: Food M\u00e4rktle\n- 10) Workation: Location\n- 11) Stadtteile/Ortschaften: Mit nachhaltigen Mobilit\u00e4tskonzepten erlebbar machen\n\n- 12) Neugestaltung Tourist Information\n- 13) Reisegruppen\n- 14) Kulinarik: Konzept\n- 15) Kultur: Veranstaltungen in der Nebensaison\n- 16) Workation: Event\n- 17) Standortmarketing: Recruiting-Ma\u00dfnahmen\n- 18) Zielgruppen: (Multisensorische) Informationen im \u00f6ffentlichen Raum\n\n![Realizing Progress](https://example.com/image0)\n\n# Schl\u00fcsselprojekte Profilierungsthema Natur & Aktiv\n\n- 19) Wasser: B\u00e4chle und Trinkbrunnen\n- 20) Wasser: Erlebnis an der Dreisam\n- 21) Attraktivierung und Ausflugsziel Tuniberg\n- 22) Attraktivierung und Ausflugsziel Schauinsland\n- 23) Aktiv: Radfahren: Marketing\n- 24) Aktiv: Mountainbike f\u00fcr alle: Governance\n- 25) Steigerung der Attraktivit\u00e4t nachhaltiger Mobilit\u00e4tskonzepte f\u00fcr Aktiv-Reisende\n\n![Freiburg Logo](https://example.com/image7)\n\n![Now](https://example.com/image8)\n\n![Realizing Progress](https://example.com/image0)\n\n# Schl\u00fcsselprojekte Thema MICE & Gesch\u00e4ftsreisen\n\n- 26) Customer Journey (Kundenreise) bei MICE & Gesch\u00e4ftsreisen\n- 27) Markenkonforme Kommunikations- und Vertriebsstrategie\n- 28) Markenkonforme Gestaltung FWTM-eigener Locations\n- 29) Erarbeitung Code of Conduct (Verhaltenskodex)\n- 30) Schaffung von markenkonformen Produkt-Bausteinen\n\n![Freiburg](https://example.com/image7)\n\n![Now](https://example.com/image8)\n\n![Realizing Progress](https://example.com/image0)\n\n# Schl\u00fcsselprojekte Basisthema Nachha ...
#   "sectionizer_type": "RELATED_TOPICS"
# }
#
# Run output:
# {
#   "output": null
# }
# Input data:
# {
#   "file": "\u00d6ffentliche Sitzung\n\ndes Ortschaftsrates Munzingen\n\nam 10.03.2021\n\nin der Schlo\u00dfbuckhalle in Munzingen in Freiburg im Breisgau\n\nErgebnismitteilung\n\nAnwesend:\n\nOrtschaftsr\u00e4tinnen und Ortschaftsr\u00e4te mit Stimmrecht:\n\nOrtsvorsteher Christian Schildecker          Ortsverwaltung Munzingen\nOrtschaftsr\u00e4tin Elisabetha Gr\u00e4fin von Kageneck\nOrtschaftsrat Clemens Lang\nOrtschaftsrat Toni Luhr\nOrtschaftsr\u00e4tin Liliane Moser\nOrtschaftsrat Klaus Riemann\nOrtschaftsrat Philipp Schillinger\nOrtschaftsrat Wolfgang Schmid\nOrtschaftsrat Ulrich Schopp\nOrtschaftsr\u00e4tin Kunigunde Stifel\nOrtschaftsr\u00e4tin Katja Weber\nOrtschaftsr\u00e4tin Katharina Wirth\n\nEs fehlte: Alle R\u00e4te waren anwesend\n\nG\u00e4ste / Sachkundige und Sachverst\u00e4ndige: Referentin Frau Eva Bengert von der Stabsstelle Beteiligungshaushalt des B\u00fcros des Ersten B\u00fcrgermeisters (EBM) von Kirchbach.\n\nVon der Verwaltung: Beate Eicher, Schriftf\u00fchrerin\n\nZur 03. Sitzung des Ortschaftsrates Munzingen wurde form- und fristgerecht eingeladen.\n\nBei Er\u00f6ffnung der regul\u00e4ren \u00f6ffentlichen Sitzung um 19:30 Uhr durch OV Schildecker war das Plenum beschlussf\u00e4hig. (Die Tagesordnung siehe Anlage 1). OV Schildecker begr\u00fc\u00dfte alle B\u00fcrgerinnen und B\u00fcrger.\n\nTOP 1\n\nFrageviertelstunde\n\nEs wurden keine Fragen gestellt.\n\nEin Munzinger B\u00fcrger \u00e4u\u00dferte eingangs die Bitte, entsprechend laut und deutlich zu kommunizieren, da die Sitzung \u00f6ffentlich sei und deshalb auch akustisch verstehbar sein m\u00fcsse.\n\n**TOP 2**\n\n**Beteiligungshaushalt 2021/2022**\n\n**hier: Bericht zum Stand der Beteiligung im Online-Forum Informations-Vorlage (Anh\u00f6rung) HFA-21/009**\n\n**Vortrag:**\nOV Schildecker begr\u00fc\u00dfte Frau Eva Bengert von der Stabsstelle Beteiligungshaushalt des B\u00fcros des Ersten B\u00fcrgermeisters von Kirchbach, hie\u00df sie herzlich willkommen und \u00fcbergab ihr das Wort. Frau Bengert bedankte sich f\u00fcr die Einladung, gab ihrer Freude Ausdruck, hier sein zu d\u00fcrfen und f\u00fchrte via PowerPoint Pr\u00e4sentation in die Informationsvorlage ein. Spezifisch f\u00fcr Munzingen sei bei dieser Vorlage z.B. der Neubau eines Jugendhauses mit Skateranlage sowie eines Gel\u00e4ndebolzplatzes.\n\n**Wortmeldungen:**\nOV Schildecker  \nOR\u00e4tin von Kageneck  \nOR Riemann  \nFrau Bengert  \n\n**Ergebnis**\n\nDer Ortschaftsrat Munzingen hat diese Informationsvorlage einstimmig zur Kenntnis genommen\n\n**TOP 3**\n\n**Rahmenplan Tuniberg, bisheriges Verfahren und weitere Vorgehensweise**\n\n**Vortrag:**\nOV Schildecker erinnerte an die vorangegangenen Sitzungen in dieser Sache, die sich als z\u00e4h, umst\u00e4ndlich und wenig greifbar erwiesen und stellte die Frage an die \u00fcbrigen R\u00e4te wie diese das seinerzeitige Begleitteam empfunden hatten?\n\n**Wortmeldungen:**\nOR\u00e4tin Stifel  \nOR\u00e4tin von Kageneck  \nOR Schmidt  \nOR Schillinger  \nOR Riemann  \n\n**Protokoll der OR-Sitzung vom 10.03.2021**\n\nOV Schildecker\n\nMan einigte sich final dahingehend, sich zu einer n\u00f6 Sitzung zu treffen und in dieser Sache zusammenzusetzen.\n\n**TOP 4**\n\n**Mechanische Abgrenzung zur Flucht Reinachstra\u00dfe durch Poller, um verbotswidriges Einfahren vom ,Munzinger Schlattweg' zu unterbinden**\n\n**Vortrag:**\nOV Schildecker wies eingangs darauf hin, dass der ORat dieses Thema bereits schon zweimal auf der Tagesordnung hatte, im Laufe der Nutzung jedoch immer wieder \u00c4nderungen entstehen k\u00f6nnten, so dass man es immer wieder mal thematisieren m\u00fcsse.\n\n**Wortmeldungen:**\nOR Schmid  \nOV Schildecker  \nOR Schillinger  \nOR\u00e4tin von Kageneck  \nOR Riemann  \n\nDieser Antrag wurde mit 8-Ja-Stimmen und 3 Enthaltungen (OR Schillinger ohne Stimmberechtigung, da befangen, weil dort wohnhaft)\n\n**TOP 5**\n\n**Verschiedenes**\n\n**Vortrag:**\nOV Schildecker wies bez\u00fcglich der Munzinger Glascontainer darauf  ...
#   "sectionizer_type": "NOT_RELATED_TOPICS"
# }
#
# Run output:
# {
#   "output": null
# }
# 42it [00:00, 132.27it/s]
# LangChain evaluation results: <ExperimentResults Sectionizer Evaluation LangChain-f6e9b5cd>

# %%
# Import necessary libraries
from neo4j import GraphDatabase

# Neo4j connection details
uri = "neo4j+s://efdb5c8e.databases.neo4j.io"  # Neo4j Aura URI
username = "neo4j"  # Default username for Neo4j
password = "ipzncqdCIFfFo87sMyKnAJ1p-D8ecUcGsxJdr2vLH_k"  # Provided password

# Function to create a Neo4j driver
def create_neo4j_driver():
    return GraphDatabase.driver(uri, auth=(username, password))

# Function to close the Neo4j driver
def close_neo4j_driver(driver):
    driver.close()

# Function to create nodes and relationships in Neo4j
def create_graph(driver, data):
    with driver.session() as session:
        # Create nodes for sections
        for i, section in enumerate(data['sections']):
            session.run(
                "CREATE (s:Section {id: $id, content: $content})",
                id=f"section_{i}", content=section[:500]  # Using first 500 characters
            )
        
        # Create relationships between sections
        for i in range(len(data['sections']) - 1):
            session.run(
                "MATCH (s1:Section {id: $id1}), (s2:Section {id: $id2}) "
                "CREATE (s1)-[:NEXT]->(s2)",
                id1=f"section_{i}", id2=f"section_{i+1}"
            )

        # Create a node for the document and link it to sections
        session.run(
            "CREATE (d:Document {type: $type}) "
            "WITH d "
            "MATCH (s:Section) "
            "CREATE (d)-[:CONTAINS]->(s)",
            type=data['sectionizer_type']
        )

# Utility function to perform custom queries
def execute_query(driver, query, parameters=None):
    with driver.session() as session:
        result = session.run(query, parameters)
        return [record.data() for record in result]

# Main execution
try:
    driver = create_neo4j_driver()
    
    # Assuming 'results' contains the evaluation data
    for result in results:
        create_graph(driver, result)
    
    print("Graph created successfully in Neo4j")

    # Example usage of the utility function
    custom_query = "MATCH (d:Document)-[:CONTAINS]->(s:Section) RETURN d.type, count(s) as section_count"
    query_result = execute_query(driver, custom_query)
    print("Custom query result:", query_result)

except Exception as e:
    print(f"An error occurred: {e}")
finally:
    close_neo4j_driver(driver)
# Out:
# An error occurred: name 'results' is not defined

# %%
# Query to get an overview of the graph structure
query = """


MATCH (f:File)-[:FILE_HAS_FILE_SECTION]->(h:HqFileSection)
RETURN f, h
"""
result = execute_query(driver, query)
print(result)
# Out:
# /var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_14022/3041946631.py:46: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with driver.session() as session:
# [{'f': {'date': '2022-05-16', 'file_name': '20220516132044-0_ni_2022-BehB-7_5.pdf', 'created': neo4j.time.DateTime(2024, 9, 13, 0, 0, 0, 0, tzinfo=pytz.FixedOffset(120)), 'access_url': 'https://ris.freiburg.de/documents.php?id=69&inline=1&document_type_id=11&meeting_attachment_id=ni_2022-BehB-7%7C20220516132044-0_ni_2022-BehB-7_5.pdf', 'sectionizer_reason': 'Das Dokument befasst sich umfassend mit dem Thema der kommunalen Teilhabeplanung (THP) für Menschen mit Behinderungen in Freiburg. Es behandelt verschiedene Aspekte und Unterthemen dieses Hauptthemas, bleibt jedoch stets auf das übergeordnete Thema der Teilhabeplanung fokussiert.', 'type': 'https://schema.oparl.org/1.0/File', 'extracted_text': 'Kommunale Teilhabeplanung (THP) für Menschen mit Behinderungen\nInformation des Beirats für Menschen mit Behinderung der Stadt Freiburg\nBehindertenbeirat Freiburg Seite 1 29.03.2022\nAmt für Soziales Teilhabeplanung und Psychiatriekoordination\n\nBegriffsklärung Teilhabeplanung (THP)\n\n„Teilhabeplanung“ ist der gewachsene Begriff für die Fachsozialplanung von Angeboten für Menschen mit Behinderung und wird zur Zeit durch „Kommunale Teilhabeplanung“ abgelöst.\n\nDer Begriff „Teilhabeplanung“ hat durch das BTHG einen neuen und anderen Sinngehalt bekommen (Planung im Einzelfall).\n\nWICHTIG: Die Erkenntnisse aus der Gesamtplanung / Teilhabeplanung des Fallmanagement sind in der Strukturplanung (auch THP) zu berücksichtigen.\nBehindertenbeirat Freiburg Seite 2 29.03.2022\nAmt für Soziales Teilhabeplanung und Psychiatriekoordination\n\nWas ist kommunale Teilhabeplanung?\nJährliche Datenerhebung\n(Eingliederungshilfe)\n\uf0d8 Angebotsstruktur für Menschen mit geistiger und körperlicher Behinderung (Teilhabeplanung, Frau Link)\n\uf0d8 Angebotsstruktur für Menschen mit psychischer Beeinträchtigung (Psychiatriekoordination, Frau Kubbutat)\nBehindertenbeirat Freiburg Seite 3 29.03.2022\nAmt für Soziales Teilhabeplanung und Psychiatriekoordination\n\nWas ist kommunale Teilhabeplanung?\nAustausch\n\uf0d8 Leistungserbringer\nund -anbieter, Leistungsträger Eingliederungshilfe, Betroffene, Angehörige\nHandlungsempfehlungen\nBehindertenbeirat Freiburg Seite 4 29.03.2022\nAmt für Soziales Teilhabeplanung und Psychiatriekoordination\n\nWozu macht man kommunale Teilhabeplanung?\n\uf076 Orientierung - Was gibt es?\n\uf076 Planung und Steuerung bedarfsgerechter\nAngebote - Was wird benötigt?\n\uf076 Weiterentwicklung - Wohin soll es gehen und\nwer tut es?\nBehindertenbeirat Freiburg Seite 5 29.03.2022\nAmt für Soziales Teilhabeplanung und Psychiatriekoordination\n\nWelcher Prozess kommt durch THP zustande?\nDaten\nUmsetzungen,\nneue Angebote\nAuswertung\nHandlungsempfehlungen\nGespräche\nWorkshops\nBehindertenbeirat Freiburg Seite 6 29.03.2022\nAmt für Soziales Teilhabeplanung und Psychiatriekoordination\n\nWelche Lebensbereiche sind drin?\nMenschen mit geistiger und körperlicher Behinderung\nBeide\nMenschen mit psychischer Beeinträchtigung\nKindergarten und Schule (Kinder und Jugendliche)\nWohnen (Besondere Wohnform und ambulante Begleitung)\nKliniken\nArbeit und Beschäftigung (z. B. Werkstatt für Menschen mit Behinderung)\nBeratung\nSenioren / Ältere Menschen\nRehabilitation\nBehindertenbeirat Freiburg Seite 7 29.03.2022\nAmt für Soziales Teilhabeplanung und Psychiatriekoordination\n\nWonach genau wird gefragt?\nMenschen mit geistiger und körperlicher Behinderung\nBeide\nMenschen mit psychischer Beeinträchtigung\n\uf076 Art der Behinderung\nMännlich / weiblich • Geburtsjahr • Nationalität • Aktuell noch: Hilfebedarfsgruppe\nPflegegrad\n\uf076 Diagnose \uf076 Familienstand \uf076 Bildungsabschluss\no Leistungsträger (wer bezahlt?) o Angebot (z.B. Wohnen ohne\ntagesstrukturierendes Angebot; tagesstrukturierendes Angebot; unterstütztes Wohnen)\n\uf076 Jahr der Aufnahme\nBehindertenbeirat Freiburg Seite 8 29.03.2022\nAmt für Soziales Teilhabeplanung und Psychiatriekoordination\n\nWorauf genau wird geschaut?\n1. Angebote, die es in Freiburg gibt und wie  ...

# %%
# Map file texts to array of sections texts
file_sections = {}

for item in result:
    file = item['f']
    section = item['h']
    
    file_id = file['id']
    section_text = section['text']
    
    if file_id not in file_sections:
        file_sections[file_id] = {
            'file_name': file['file_name'],
            'extracted_text': file['extracted_text'],
            'sections': []
        }
    
    file_sections[file_id]['sections'].append(section_text)

# Print the result
for file_id, file_data in file_sections.items():
    print(f"File: {file_data['file_name']}")
    print(f"Number of sections: {len(file_data['sections'])}")
    print("First 100 characters of extracted text:", file_data['extracted_text'][:100])
    print("First 100 characters of each section:")
    for i, section_text in enumerate(file_data['sections'], 1):
        print(f"  Section {i}: {section_text[:100]}")
    print()
# Out:
# File: 20220516132044-0_ni_2022-BehB-7_5.pdf
# Number of sections: 1
# First 100 characters of extracted text: Kommunale Teilhabeplanung (THP) für Menschen mit Behinderungen
# Information des Beirats für Menschen
# First 100 characters of each section:
#   Section 1: Kommunale Teilhabeplanung (THP) für Menschen mit Behinderungen
# Information des Beirats für Menschen
#
# File: 20200313115729-0_ni_2020-MIA-2_2.pdf
# Number of sections: 6
# First 100 characters of extracted text: Dezernat III -
# Freiburg, den 13.03.2020 Tel.: 3012 / Frau Müller
# Ergebnismitteilung
# zur 1. Sitzung d
# First 100 characters of each section:
#   Section 1: 3 -
#
#   Section 2:
# Auf Nachfrage aus dem Gremium werden von der Verwaltung die Regelungen für Sachkundige und Sachvers
#   Section 3: - Drucksache ASW-20/002 - zur Information
#
# Ergebnis
# Der Ausschuss für Migration und Integration nimm
#   Section 4: - mündlicher Bericht -
#
# Ergebnis
# Frau Dr. Niethammer, Leiterin des Amtes für Migration und Integrati
#   Section 5:
# Es erfolgt ein Hinweis auf die Ausstellung „Weltenfrauen“ im Rahmen des Stadtjubiläums vom 04.03. b
#   Section 6: die 1. Sitzung des Ausschusses für Migration und Integration am 5. März 2020 brachte folgende Ergebn
#
# File: 20170621144830_ni_2017-UA-155_4.pdf
# Number of sections: 1
# First 100 characters of extracted text: Stadt Freiburg im Breisgau · Bürgermeisteramt Dezernat II Postfach, D-79095 Freiburg An die Mitglied
# First 100 characters of each section:
#   Section 1: Stadt Freiburg im Breisgau · Bürgermeisteramt Dezernat II Postfach, D-79095 Freiburg An die Mitglied
#
# File: 20230320161107-0_4892110100244_1.pdf
# Number of sections: 2
# First 100 characters of extracted text: CDU Stadtratsfraktion Freiburg | Rathausplatz 4 | 79098 Freiburg
# Herrn Oberbürgermeister Martin Horn
# First 100 characters of each section:
#   Section 1: STADTRATSFRAKTION CDU FREIBURG
#
#   Section 2:
# Begründung:
#
# Der Zukunftsfond Klimaschutz stellt wichtige Weichen für eine nachhaltige Stadt und wi
#
# File: 2.pdf
# Number of sections: 1
# First 100 characters of extracted text:
#
#
#
#
# First 100 characters of each section:
#   Section 1: Es wurden keine Textbausteine bereitgestellt. Bitte geben Sie die durch OCR extrahierten Textbaustei
#
# File: 2.pdf
# Number of sections: 1
# First 100 characters of extracted text:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# First 100 characters of each section:
#   Section 1: Übersichtskarte
#
# UEP zum B-Plan „Vordere Steige“, Plan-Nr. 2-7
#
# Neuberg
#
# 2
#
# ANLAGE 2 ZUR DRUCKSACHE
#
# File: 2401911100009
# Number of sections: 1
# First 100 characters of extracted text: DRUCKSACHE G-10/010
# B E S C H L U S S - V O R L A G E
# Dezernat/Amt:
# I / Stadtplanungsamt
# Verantwortl
# First 100 characters of each section:
#   Section 1: DRUCKSACHE G-10/010
# - 2 -
# 31. Juli 2009 (BGBl. I S. 2585), hat der Gemeinderat in seiner Sitzung am
#
# File: 2402708100208
# Number of sections: 1
# First 100 characters of extracted text: DRUCKSACHE G-10/199
# B E S C H L U S S - V O R L A G E
# Dezernat/Amt:
# I/Haupt- und Personalamt
# Verantw
# First 100 characters of each section:
#   Section 1: DRUCKSACHE G-10/199
# B E S C H L U S S - V O R L A G E
# Dezernat/Amt: Verantwortlich: Tel.Nr.: Datum
# I
#
# File: 20110217140101.pdf
# Number of sections: 1
# First 100 characters of extracted text:
# First 100 characters of each section:
#   Section 1: Freiburg
# IM BREISGAU
# Zuschussantrag/Mittelanmeldung
# Sozial- und Jugendhilfe Haushaltsjahre 2011/2012
#
# File: 20171106104835.pdf
# Number of sections: 1
# First 100 characters of extracted text: Anlage 4 zur DRUCKSACHE G-17/198
# Kalkulation der Gebühr für die Benutzung der Feierhallen, Aufbahrun
# First 100 characters of each section:
#   Section 1: Seite 3 -
#
# Wandbeleuchtung
#
# Anzünden 20 Min.
# Löschen 10 Min.
# 30 Min. x 48 € = 24,00 €
#
# Kerzen 48 x
#
# File: 790203100081
# Number of sections: 1
# First 100 characters of extracted text: 1 -
# DRUCKSACHE G 97069
# B E S C H L U ß - V O R L A G E
# Dezernat/Amt:
# Bearbeitet von:
# Tel.Nr.:
# Datum
#
# First 100 characters of each section:
#   Section 1: 1 - DRUCKSACHE G 97069
# BESCHLUß - VORLAGE
# Dezernat/Amt: Bearbeitet von: Tel.Nr.: Datum
# II/Schul- und
#
# File: 4630510100234
# Number of sections: 1
# First 100 characters of extracted text: DRUCKSACHE G-21/226
# B E S C H L U S S V O R L A G E
# Dezernat / Amt
# V / Amt für Projektentwicklung un
# First 100 characters of each section:
#   Section 1: - 4 - DRUCKSACHE G-21/226
#
# Breisacher Hof
# Förderrahmen (100 %) Finanzhilfen Bund / Land (60 %) Kompl
#
# File: 20220615082036-0.pdf
# Number of sections: 27
# First 100 characters of extracted text: Anlage 4 zur DRUCKSACHE G-22/117
# 29. Änderung des Flächennutzungsplans 2020 „Kleineschholz“
# Entschei
# First 100 characters of each section:
#   Section 1: Anlage 4 zur DRUCKSACHE G-22/117
#
#
#   Section 2: 29. Änderung des Flächennutzungsplans 2020 „Kleineschholz“
#
#
#   Section 3: Entscheidungsvorschläge zu den während der frühzeitigen Öffentlichkeits- und Behördenbeteiligung ein
#   Section 4:
# Nach der mündlichen Auskunft der Behörde ist eine Gebäudehöhe von ca. max. 20 m unbedenklich. Im Be
#   Section 5: A.6 Industrie- und Handelskammer Südlicher Oberrhein (Schreiben vom 06.09.2019)
# A.6.1 Grundsätzliche
#   Section 6: A.1 Eisenbahn-Bundesamt (Schreiben vom 23.07.2019) Ich weise darauf hin, dass Flächen einer Ei- senb
#   Section 7:
# A.5 Regierungspräsidium Freiburg – Landesamt für Geologie, Rohstoffe und Bergbau (Schreiben vom 04.
#   Section 8:
# Der Hinweis ist nicht Gegenstand der 29. Änderung des FNP 2020, sondern betrifft das parallele Beba
#   Section 9:
# - 4 -
#
# der Güterbahnlinie mit einbezogen und in relevanter Weise geändert werden. Es bleibt offen,
#   Section 10:
# Anmerkung: Vermutlich liegt hier ein Missverständnis seitens des Einwenders vor. Da vom Einwender u
#   Section 11:
# A.6.7 Es wird angeregt, auch in o.a. Zusammenhang (s.,,*") diesen für Erschließung und Bündelung de
#   Section 12:
# Der Hinweis wird zur Kenntnis genommen. Planungsrechtliche Festsetzungen betreffen nicht die 29. Än
#   Section 13:
# A.6.12 Gegenüber der (nur) auf der städtischen Homepage zu findenden, wirksamen Fassung des FNP 202
#   Section 14:
# A.6.4 Bislang können die Ausführungen zu den verkehrlichen Auswirkungen der 3 untersuchten Variante
#   Section 15:
# Die Hinweise werden zur Kenntnis genommen. Die Erreichbarkeit der Agentur für Arbeit (AfA) wird dur
#   Section 16: B.1 Bürgerverein Betzenhausen-Bischoflinde (Schreiben vom 04.09.2019)
# B.1.1 Erweiterung Bebauungspla
#   Section 17:
# B.1.4 Fahrradwegverbindung
# Wichtig wäre für den Stadtteil Betzenhausen-Bischofslinde eine attraktiv
#   Section 18: B.2 Handelsverband Südbaden (Schreiben vom 27.08.2019)
#
# B.2.1 Die Planung, zusätzlich bezahlbare Mie
#   Section 19: B.2.2 Die Bedenken der Gewerbetreibenden konnten durch die bisherigen Veranstaltungen nicht ausgeräu
#   Section 20: Betzenhausen mit dem Kfz anfahren und dort einkaufen möchten, können dies ohne Erschwernis weiterhin
#   Section 21: B.3.1 Wie bereits mit Schreiben an die Stadt vom 21.7.2017 mitgeteilt, befürworten wir Wohnbau und K
#   Section 22: C.5 Deutsche Telekom Technik GmbH (Schreiben vom 02.09.2019)
# C.6 Regierungspräsidium Stuttgart – Tec
#   Section 23:
# B.4.2
#
# Die farbigen Linien verstehen sich als Punkt-zu-Punkt-Richtfunkverbindungen der Telefonica G
#   Section 24:
# Sollten sich noch Änderungen in der Planung/Planungsflächen ergeben, so würden wir Sie bitten uns d
#   Section 25:
# Anlage: digitales Bild, welches den Verlauf der Punkt-zu-Punkt-Richtfunkverbindung verdeutlichen so
#   Section 26:
# Der südliche Parkplatz der Agentur für Arbeit wird umgewandelt in eine öffentliche Grünfläche und d
#   Section 27:
# Vgl. B.3.1 bis B.3.3. Die Klimabelange wurden im parallelen Bebauungsplan durch eine Vielzahl von F
#
# File: 20230607100109-3.pdf
# Number of sections: 1
# First 100 characters of extracted text: Anlage 1 zur DRUCKSACHE G-23/029
# Finanzielle Auswirkungen -
# Bereich: Teilhaushalt / Teilbudget: Prod
# First 100 characters of each section:
#   Section 1: Anlage 1 zur DRUCKSACHE G-23/029
#
# - Finanzielle Auswirkungen -
#
# Bereich: Doppelhaushalt / Stadt Frei
#
# File: 20071012113013.pdf
# Number of sections: 1
# First 100 characters of extracted text: Anlage 1 zur Drucksache G-07/183.1 (ersetzt Anlage 1 der Drucksache G-07/183)
# Gesamtübersicht: Aufte
# First 100 characters of each section:
#   Section 1: Anlage 1 zur Drucksache G-07/183.1 (ersetzt Anlage 1 der Drucksache G-07/183)
# Gesamtübersicht: Aufte

# %%
from langsmith import Client
import os

# Setup Langsmith client
os.environ["LANGCHAIN_PROJECT"] = "neurabot-ca-evaluation"
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_ENDPOINT"] = "https://eu.api.smith.langchain.com"
os.environ["LANGCHAIN_API_KEY"] = "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"
client = Client(api_key="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", api_url="https://eu.api.smith.langchain.com")

# Create dataset
dataset = []
for file_id, file_data in file_sections.items():
    dataset.append({
        "input": {"file_text": file_data['extracted_text']},
        "output": {"sections": file_data['sections']}
    })

# Save to Langsmith
dataset_name = "File_Sections_Datasets"
langsmith_dataset = client.create_dataset(dataset_name, description="File texts and their corresponding sections")

# Create examples in the dataset
client.create_examples(
    inputs=[item["input"] for item in dataset],
    outputs=[item["output"] for item in dataset],
    dataset_id=langsmith_dataset.id,
)

print(f"Created dataset '{dataset_name}' with {len(dataset)} examples.")
# Out:
# Created dataset 'File_Sections_Datasets' with 15 examples.
