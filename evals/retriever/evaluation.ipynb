# %%
from langchain_community.vectorstores import Neo4jVector
from langchain_openai import AzureOpenAIEmbeddings
from dotenv import load_dotenv
import os
from langchain_cohere import CohereEmbeddings

load_dotenv()

embeddings = CohereEmbeddings(model="embed-multilingual-v3.0")



neo4j_vector_retriever = Neo4jVector.from_existing_index(embeddings, index_name="file_chunks").as_retriever(search_kwargs={"k": 10})

# %%
from neo4j import GraphDatabase

neo4j_graph = GraphDatabase.driver(uri=os.environ["NEO4J_URI"], auth=(os.environ["NEO4J_USERNAME"], os.environ["NEO4J_PASSWORD"]))

# %%
query = "MATCH (n) RETURN count(n) as count"

with neo4j_graph.session() as session:
    result = session.run(query)
    count = result.single()[0]

print(f"Number of nodes in the graph: {count}")
# Out:
# Number of nodes in the graph: 103882

# %%
# Calculate Corvee vector using Cohere
from langchain_cohere import CohereEmbeddings

# Initialize Cohere embeddings
cohere_embeddings = CohereEmbeddings(model="embed-multilingual-v3.0")

# Define a search prompt (you may want to replace this with your actual search prompt)
search_prompt = "Your search prompt here"

# Calculate the Corvee vector
corvee_vector = cohere_embeddings.embed_query(search_prompt)

print(f'Corvee vector length: {len(corvee_vector)}')
print(f'Corvee vector sample: {corvee_vector[:10]}')
print(f'Result:')

# You may want to adjust this Cypher query based on your specific Neo4j setup
cypher_query = '''
CALL db.index.vector.queryNodes("file_chunks", 10, $queryVector)
YIELD node, score
RETURN node.id AS id,
    node.text AS text,
    score
'''

# Execute the Cypher query (assuming you have a Neo4j connection set up)
with neo4j_graph.session() as session:
    result = session.run(cypher_query, queryVector=corvee_vector)
    for record in result:
        print(f"ID: {record['id']}, Score: {record['score']}")
        print(f"Text: {record['text'][:100]}...")  # Print first 100 characters of text
        print("---")
# Out:
# Corvee vector length: 1024
# Corvee vector sample: [0.010772705, 0.018371582, -0.052825928, 0.031677246, -0.030197144, -0.03338623, -0.010223389, -0.021606445, -0.023880005, 0.01687622]
# Result:
# ID: b6f21ac7-beeb-453f-8a7b-c22bd3b2188a, Score: 0.7287719249725342
# Text: - 3 -...
# ---
# ID: 2e25a206-7003-4d84-a644-4be29c30d3d4, Score: 0.7287719249725342
# Text: - 3 -...
# ---
# ID: 89927bbf-996d-439c-9ab7-1a34f0d3c227, Score: 0.7287719249725342
# Text: - 3 -...
# ---
# ID: 0289625c-a19c-4d85-aae3-bcdd8c17be07, Score: 0.7287719249725342
# Text: - 3 -...
# ---
# ID: bc186d80-25b9-46d6-b58d-6cfb42c351a6, Score: 0.7284402847290039
# Text: - 3 -...
# ---
# ID: 29a85b62-6244-4a3b-a46f-4d3091c1bd6c, Score: 0.7284402847290039
# Text: - 3 -...
# ---
# ID: cbeec90e-6bee-4295-b486-b39c5b1ab104, Score: 0.7283279895782471
# Text: - 3 -...
# ---
# ID: 43e85bcd-98a0-4ed7-a99c-ce5aa9672e87, Score: 0.7267098426818848
# Text: - 2 -...
# ---
# ID: 1733c0a2-0a81-462a-8efd-6cfcb0959b73, Score: 0.7266347408294678
# Text: - 2 -...
# ---
# ID: 2b92ab79-1f4d-42a3-a261-9e4432df5626, Score: 0.7265973091125488
# Text: - 8 -...
# ---

# %%
# next parent doc retrieval

pdr_cypher ="""

MATCH (node)-[]-(fs_FileSection)-[]-(f:File)
WITH f, max(score) AS score // deduplicate parents
RETURN f.extracted_text AS text, score, {source: f.id} AS metadata
"""

# %%
parent_document_retriever = Neo4jVector.from_existing_index(embeddings, index_name="file_chunks", retrieval_query=pdr_cypher).as_retriever()

# %%
from langchain_core.runnables import chain
from neurapolis_retriever.graph import graph as retriever_graph
from langchain_core.documents import Document

# @chain
# def graph_retriever_chain(query):


#     state = {"query": query}
#     results = retriever_graph.invoke(state)

#     searches = results.get('searches', [])
#     docs = []

#     for search in searches:
#         hits = search.hits if hasattr(search, 'hits') else []
#         for hit in hits:
#             print(hit)
#             if hasattr(hit, 'related_file') and hit.related_file is not None:
#                 if hasattr(hit.related_file, 'extracted_text'):
#                     docs.append(Document(page_content=hit.related_file.extracted_text))

#     print(f"Number of extracted texts: {len(docs)}")

#     for i, doc in enumerate(docs, 1):
#         print(f"Extracted text {i}:")
#         print(doc.page_content[:500])  # Print first 500 characters of each text
#         print("\n---\n")

#     return docs

# %%
from langsmith import Client
from langsmith.evaluation import evaluate

import os
from dotenv import load_dotenv

load_dotenv()

client= Client(api_key=os.environ["LANGCHAIN_API_KEY"], api_url=os.environ["LANGCHAIN_ENDPOINT"])

# Define dataset: these are your test cases

from langsmith import Client
from langsmith.evaluation import evaluate
from langchain_openai import AzureChatOpenAI
from langsmith.evaluation import evaluate
from langsmith.schemas import Example, Run
from langchain_core.documents import Document

def document_id_matcher(root_run: Run, example: Example) -> dict:
    """
    Evaluates if any retrieved document matches the expected document ID.
    Supports both graph retriever output and standard document output.
    """
    example_output_id = example.outputs.get('f.id', '')
    
    if root_run.outputs:
        if 'searches' in root_run.outputs:
            # Graph retriever output
            searches = root_run.outputs['searches']
            for search in searches:
                if hasattr(search, 'hits'):
                    for hit in search.hits:
                        if hasattr(hit, 'related_file') and hit.related_file is not None:
                            doc_id = getattr(hit.related_file, 'id', None)
                            if doc_id == example_output_id:
                                comment = f"Found document with matching ID: {example_output_id}. Search type: {search.type.value}"
                                print(comment)
                                return {"key": "document_id_match", "score": 1.0, "comment": comment}
        elif 'output' in root_run.outputs:
            # Standard document output
            output = root_run.outputs['output']
            if isinstance(output, list) and output and isinstance(output[0], Document):
                for doc in output:
                    doc_id = doc.metadata.get('source')
                    if doc_id == example_output_id:
                        comment = f"Found document with matching source ID: {example_output_id}. Search type: Standard"
                        print(comment)
                        return {"key": "document_id_match", "score": 1.0, "comment": comment}

    comment = f"No document found with matching ID: {example_output_id}"
    print(comment)
    return {"key": "document_id_match", "score": 0.0, "comment": comment}



def document_relevance_grader(root_run: Run, example: Example) -> dict:
    
    print("root_run", root_run)
    """
    A simple evaluator that checks if retrieved documents are relevant to the question
    """
    doc_txt = ""
    input_question = example.inputs.get('question', '')
    


    if root_run.outputs and 'output' in root_run.outputs:
        output = root_run.outputs['output']
        if isinstance(output, list) and output and isinstance(output[0], Document):
            limited_docs = output
            doc_txt = "\n\n".join(doc.page_content for doc in limited_docs)
            
    us_client = Client(api_key="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")
    llm = AzureChatOpenAI(deployment_name="gpt-4o-mini", temperature=0)
    grade_prompt_doc_relevance = us_client.pull_prompt("rag-document-relevance")
    answer_grader = grade_prompt_doc_relevance | llm

    if not doc_txt:
        doc_txt = "No relevant documents found."

    score = answer_grader.invoke({"input":{
        "question": input_question,
        "documents": doc_txt 
    }})

    return {"key": "document_relevance", "score": float(score["Score"])}

# %%
os.environ["LANGCHAIN_PROJECT"] = "neurapolis-retriever-evaluations"
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_ENDPOINT"] = "https://eu.api.smith.langchain.com"
os.environ["LANGCHAIN_API_KEY"] = "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"

# %%
outputs = None

import json
def example_evaluator(root_run: Run, example: Example) -> dict:

    
    global outputs
    outputs = root_run.outputs
    print(outputs)
    
    # Store run to file
    run_data = json.dumps(root_run.dict(), default=str, indent=2)
    with open('root_run_debug.txt', 'w') as f:
        f.write(run_data)
    # global outputs
    # outputs = root_run.outputs
    # print(outputs)


    return {"key": "example", "score": 1.0}

# %%
outputs

# %%
import langsmith
from langsmith.evaluation import EvaluationResult
from neurapolis_retriever.state import *

def evaluate_search(query, search_type, hits):
    gradings = []
    feedback_summary = []
    for hit in hits:
        if hasattr(hit, 'grading') and hit.grading is not None:
            gradings.append(hit.grading)
            feedback_summary.append({
                'is_relevant': hit.grading.is_relevant,
                'feedback': hit.grading.feedback,
                'file_id': hit.file_chunk.id if hasattr(hit, 'file_chunk') else None
            })
    
    relevant_gradings = [grading for grading in gradings if grading.is_relevant]
    irrelevant_gradings = [grading for grading in gradings if not grading.is_relevant]
    
    summary = summarize_gradings(relevant_gradings, irrelevant_gradings, feedback_summary)
    
    return {
        "query": query,
        "type": search_type,
        "relevant_hits": len(relevant_gradings),
        "irrelevant_hits": len(irrelevant_gradings),
        "summary": summary
    }

def evaluate_search_level(level, searches):
    level_summary = {
        "level": level,
        "queries": [],
        "total_relevant_hits": 0,
        "total_irrelevant_hits": 0,
        "summary": ""
    }
    
    for search in searches:
        if search.level == level:
            result = evaluate_search(search.query, search.type, search.hits)
            level_summary["queries"].append({"query": result["query"], "type": result["type"]})
            level_summary["total_relevant_hits"] += result["relevant_hits"]
            level_summary["total_irrelevant_hits"] += result["irrelevant_hits"]
            level_summary["summary"] += f"{result['summary']}\n"
    
    return level_summary

def summarize_gradings(relevant_gradings, irrelevant_gradings, feedback_summary):
    summary = f"Total gradings: {len(relevant_gradings) + len(irrelevant_gradings)}\n"
    summary += f"Relevant gradings: {len(relevant_gradings)}\n"
    summary += f"Irrelevant gradings: {len(irrelevant_gradings)}\n\n"
    summary += "Feedback summary:\n"
    for item in feedback_summary:
        relevance = "Relevant" if item['is_relevant'] else "Irrelevant"
        summary += f"- {relevance}: {item['feedback']} (File ID: {item['file_id']})\n"
    return summary

def evaluate_run(run: Run, example: Example) -> EvaluationResult:
    outputs = run.outputs
    searches = outputs['searches']
    results = []
    for search in searches:
        result = evaluate_search(search.query, search.type, search.hits)
        results.append(result)
    
    level_0_summary = evaluate_search_level(0, searches)
    level_1_summary = evaluate_search_level(1, searches)
    
    return EvaluationResult(
        key="custom_rag_evaluation",
        score=level_0_summary["total_relevant_hits"] / (level_0_summary["total_relevant_hits"] + level_0_summary["total_irrelevant_hits"]) if level_0_summary["total_relevant_hits"] + level_0_summary["total_irrelevant_hits"] > 0 else 0,
        comment=f"Level 0: {level_0_summary}\nLevel 1: {level_1_summary}",
        additional_results={
            "search_results": results,
            "level_0": level_0_summary,
            "level_1": level_1_summary
        }
    )

# %%
from neurapolis_retriever.state.grading import Grading
from collections import defaultdict
from neurapolis_retriever.state.hit import HitStep

def parent_retrieval_evaluation(run: Run, example: Example) -> EvaluationResult:
    query = example.inputs.get('question', '')
    outputs = run.outputs
    if not outputs or 'searches' not in outputs or not outputs['searches']:
        return EvaluationResult(
            key="parent_retrieval_evaluation",
            score=0,
            comment="No searches found in outputs"
        )

    relevant_count = 0
    irrelevant_count = 0
    search_type_relevance = defaultdict(lambda: {"relevant": 0, "irrelevant": 0})
    
    for search in outputs['searches']:
        if search.level != 0:
            continue
        search_type = search.type.value
        if search.hits:
            for hit in search.hits:
                if hasattr(hit, 'grading') and hit.grading is not None and hit.step != HitStep.DOUBLED:
                    if hit.grading.is_relevant:
                        relevant_count += 1
                        search_type_relevance[search_type]["relevant"] += 1
                    else:
                        irrelevant_count += 1
                        search_type_relevance[search_type]["irrelevant"] += 1

    total_count = relevant_count + irrelevant_count
    if total_count == 0:
        return EvaluationResult(
            key="parent_retrieval_evaluation",
            score=0,
            comment="No graded hits found for parent retrieval"
        )
    
    relevance_score = relevant_count / total_count
    
    comment = f"Query: {query}\n"
    comment += f"Relevant hits: {relevant_count}\n"
    comment += f"Irrelevant hits: {irrelevant_count}\n"
    
    comment += "\nSearch Type Relevance:\n"
    for search_type, counts in search_type_relevance.items():
        total = counts["relevant"] + counts["irrelevant"]
        if total > 0:
            type_relevance_score = counts["relevant"] / total
            comment += f"{search_type}: {type_relevance_score:.2f} ({counts['relevant']} relevant, {counts['irrelevant']} irrelevant)\n"
    
    return EvaluationResult(
        key="parent_retrieval_evaluation",
        score=relevance_score,
        comment=comment
    )

def sub_retrieval_evaluation(run: Run, example: Example) -> EvaluationResult:
    query = example.inputs.get('question', '')
    outputs = run.outputs
    if not outputs or 'searches' not in outputs or not outputs['searches']:
        return EvaluationResult(
            key="sub_retrieval_evaluation",
            score=0,
            comment="No searches found in outputs"
        )

    relevant_count = 0
    irrelevant_count = 0
    search_type_relevance = defaultdict(lambda: {"relevant": 0, "irrelevant": 0})
    
    for search in outputs['searches']:
        if search.level != 1:
            continue
        search_type = search.type.value
        if search.hits:
            for hit in search.hits:
                if hasattr(hit, 'grading') and hit.grading is not None and hit.step != HitStep.DOUBLED:
                    if hit.grading.is_relevant:
                        relevant_count += 1
                        search_type_relevance[search_type]["relevant"] += 1
                    else:
                        irrelevant_count += 1
                        search_type_relevance[search_type]["irrelevant"] += 1

    total_count = relevant_count + irrelevant_count
    if total_count == 0:
        return EvaluationResult(
            key="sub_retrieval_evaluation",
            score=0,
            comment="No graded hits found for sub-retrieval"
        )
    
    relevance_score = relevant_count / total_count
    
    comment = f"Query: {query}\n"
    comment += f"Relevant hits: {relevant_count}\n"
    comment += f"Irrelevant hits: {irrelevant_count}\n"
    
    comment += "\nSearch Type Relevance:\n"
    for search_type, counts in search_type_relevance.items():
        total = counts["relevant"] + counts["irrelevant"]
        if total > 0:
            type_relevance_score = counts["relevant"] / total
            comment += f"{search_type}: {type_relevance_score:.2f} ({counts['relevant']} relevant, {counts['irrelevant']} irrelevant)\n"
    
    return EvaluationResult(
        key="sub_retrieval_evaluation",
        score=relevance_score,
        comment=comment
    )

def best_search_type_evaluation(run: Run, example: Example) -> EvaluationResult:
    outputs = run.outputs
    if not outputs or 'searches' not in outputs or not outputs['searches']:
        return EvaluationResult(
            key="best_search_type_evaluation",
            score=0,
            comment="No searches found in outputs"
        )

    search_type_relevance = defaultdict(lambda: {"relevant": 0, "irrelevant": 0})
    
    for search in outputs['searches']:
        search_type = search.type.value
        if search.hits:
            for hit in search.hits:
                if hasattr(hit, 'grading') and hit.grading is not None and hit.step != HitStep.DOUBLED:
                    if hit.grading.is_relevant:
                        search_type_relevance[search_type]["relevant"] += 1
                    else:
                        search_type_relevance[search_type]["irrelevant"] += 1

    best_score = 0
    best_type = None
    comment = "Search Type Relevance:\n"
    
    for search_type, counts in search_type_relevance.items():
        total = counts["relevant"] + counts["irrelevant"]
        if total > 0:
            type_relevance_score = counts["relevant"] / total
            comment += f"{search_type}: {type_relevance_score:.2f} ({counts['relevant']} relevant, {counts['irrelevant']} irrelevant)\n"
            if type_relevance_score > best_score:
                best_score = type_relevance_score
                best_type = search_type

    if best_type:
        comment += f"\nBest performing search type: {best_type}"
    else:
        comment += "\nNo search types with relevance data found"

    return EvaluationResult(
        key="best_search_type_evaluation",
        score=best_score,
        comment=comment
    )

def overall_relevance_evaluation(run: Run, example: Example) -> EvaluationResult:
    outputs = run.outputs
    if not outputs or 'searches' not in outputs or not outputs['searches']:
        return EvaluationResult(
            key="overall_relevance_evaluation",
            score=0,
            comment="No searches found in outputs"
        )

    relevant_count = 0
    irrelevant_count = 0
    
    for search in outputs['searches']:
        if search.hits:
            for hit in search.hits:
                if hasattr(hit, 'grading') and hit.grading is not None and hit.step != HitStep.DOUBLED:
                    if hit.grading.is_relevant:
                        relevant_count += 1
                    else:
                        irrelevant_count += 1

    total_count = relevant_count + irrelevant_count
    if total_count == 0:
        return EvaluationResult(
            key="overall_relevance_evaluation",
            score=0,
            comment="No graded hits found"
        )
    
    overall_score = relevant_count / total_count
    
    comment = f"Overall relevance score: {overall_score:.2f}\n"
    comment += f"Total relevant hits: {relevant_count}\n"
    comment += f"Total irrelevant hits: {irrelevant_count}\n"
    
    return EvaluationResult(
        key="overall_relevance_evaluation",
        score=overall_score,
        comment=comment
    )

evaluators = [
    parent_retrieval_evaluation,
    sub_retrieval_evaluation,
    best_search_type_evaluation,
    overall_relevance_evaluation
]

# %%
examples = list(client.list_examples(dataset_name="Freiburg_QA_ID"))
samples = examples[:1]

# %%
from neurapolis_retriever.graph import graph as graph_retriever

# %%
# result = evaluate( 
#     lambda x: graph_retriever.invoke({"query": x["question"]}),
#     data=samples,  # Recreated dataset for this experiment
#     evaluators=[document_id_matcher],
#     experiment_prefix="example",  # The name of the experiment
#     metadata={
#         "version": "1.0.0",
#         "revision_id": "beta"
#     },
#     client=client   
# )

# %%
from langchain_core.runnables import chain

@chain
def get_page_contents(query):
    results = graph_retriever.invoke({"query": query})
    searches = results.get("searches", [])
    page_contents = ""
    for search in searches[:1]:
        hits = search.hits if hasattr(search, "hits") else []
        for hit in hits:
            print(hit)
            if hasattr(hit, "related_file") and hit.related_file is not None:
                if hasattr(hit.related_file, "extracted_text"):
                    page_contents += hit.related_file.extracted_text + "\n"
                if hasattr(hit.related_file, "access_url"):
                    page_contents += f"Access URL: {hit.related_file.access_url}\n"
    return page_contents.strip()

# %%
from langchain_core.runnables import RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import AzureChatOpenAI

llm = AzureChatOpenAI(deployment_name="gpt-4o-mini", temperature=0)




prompt = client.pull_prompt("rag-prompt")

prompt

# # Convert the Prompt object to a PromptTemplate
# prompt_template = PromptTemplate(
#     input_variables=["question", "context"],
#     template=prompt.template
# )

# Create a chain using the RunnablePassthrough and PromptTemplate
chain = (
    {
        "question": RunnablePassthrough(),
        "context": get_page_contents
    } | prompt | llm | StrOutputParser()
   

)
# Out:
# /Users/pascal/neurapolis/evals/retriever/.venv/lib/python3.12/site-packages/langsmith/client.py:5301: LangChainBetaWarning: The function `loads` is in beta. It is actively being worked on, so the API may change.
#   prompt = loads(json.dumps(prompt_object.manifest))

# %%
chain.invoke("Welche Themen werden voraussichtlich in der Sitzung am 25.07.2024 behandelt??")
# Out:
# filesection_id 88c4e328-5646-43e1-9203-f909139ecd2e file https://ris.freiburg.de/oparl/file/sia%7C2024-GR-269%7C2
# filesection_id 3d0eb6f9-ec7e-41e0-90b3-dfe889c13c78 file https://ris.freiburg.de/oparl/file/sia%7C2024-GR-268%7C2
# filesection_id 30bf6011-fdb4-4f34-b141-b6918d58db56 file https://ris.freiburg.de/oparl/file/sia%7C2024-GR-268%7C1
# filesection_id fd9d62ae-9c18-48d3-92f9-46db8a542cf3 file https://ris.freiburg.de/oparl/file/sia%7C2024-GR-267%7C1
# filesection_id 7f0b864f-b857-47e8-a3e5-b07d86882d58 file https://ris.freiburg.de/oparl/file/sia%7C2024-OR_TI-115%7C3
# filesection_id 338287d2-24a2-4d4c-a7a5-fb9b5faa1d49 file https://ris.freiburg.de/oparl/file/sia%7C2024-OR_TI-115%7C3
# filesection_id 09dca5bc-ee0a-483a-9f16-8e957d5b332b file https://ris.freiburg.de/oparl/file/sia%7C2024-OR_TI-115%7C3
# filesection_id 96c16d3d-fd9a-41f2-a7d4-d8b962ee8031 file https://ris.freiburg.de/oparl/file/sia%7C2024-HFA-87%7C1
# filesection_id daa4f31b-e577-4f71-a7b0-6f3e228845c3 file https://ris.freiburg.de/oparl/file/sia%7C2024-OR_MU-94%7C2
# filesection_id 3e21f7b8-9ecd-434c-83fc-78fbe4e20bf6 file https://ris.freiburg.de/oparl/file/sia%7C2024-OR_LE-112%7C1
# filesection_id 2318fee1-ea91-483d-9fb3-5a1db91b541b file https://ris.freiburg.de/oparl/file/sia%7C2024-OR_TI-114%7C1
# filesection_id f317e770-9acf-4ee5-b192-ee8b8bf0eca9 file https://ris.freiburg.de/oparl/file/sia%7C2024-GR-264%7C1
# filesection_id d9fa69a2-c452-4164-8279-9f916119d58e file https://ris.freiburg.de/oparl/file/sia%7C2024-ASW-138%7C2
# filesection_id f363c239-cb69-4986-bb0a-251307257a71 file https://ris.freiburg.de/oparl/file/sia%7C2024-OR_TI-113%7C1
# filesection_id 69f509e9-8630-4741-a915-7f8b8f54dee0 file https://ris.freiburg.de/oparl/file/sia%7C2024-OR_LE-110%7C1
# filesection_id aacf6d44-d931-417d-a1f1-c36b69829193 file https://ris.freiburg.de/oparl/file/sia%7C2024-HFA-84%7C1
# filesection_id 78621b9d-2f27-4055-adb9-c757e2cbfaee file https://ris.freiburg.de/oparl/file/sia%7C2024-OR_OPF-95%7C1
# filesection_id 50d6e4e2-5976-461a-88c5-3a3e86ef44ff file https://ris.freiburg.de/oparl/file/sia%7C2024-OR_OPF-95%7C5
# filesection_id 8ad91f0a-90c6-4588-ad2a-23570ca436fc file https://ris.freiburg.de/oparl/file/sia%7C2024-GR-263%7C3
# filesection_id ad41ef85-3088-4582-9b18-ff94221ec98c file https://ris.freiburg.de/oparl/file/sia%7C2024-UKA-27%7C2
# filesection_id a34c1226-bc49-4163-8000-b21bbbbccc5a file https://ris.freiburg.de/oparl/file/sia%7C2024-UKA-27%7C2
# filesection_id 545e78ba-7ec3-4e54-8ba5-7ab2761dbee5 file https://ris.freiburg.de/oparl/file/sia%7C2024-AWW-8%7C3
# filesection_id c5880744-78b2-4de3-bfbb-2327972a295a file https://ris.freiburg.de/oparl/file/sia%7C2024-OR_LE-108%7C1
# filesection_id e7dbe346-0b3a-462c-8df1-36702d21edc4 file https://ris.freiburg.de/oparl/file/sia%7C2024-GR-262%7C1
# filesection_id 82132830-3e1b-4294-9e09-f216ba0c32da file https://ris.freiburg.de/oparl/file/sia%7C2024-GR-262%7C3
# filesection_id 6db88253-d28f-4002-93a2-e4ae79f81252 file https://ris.freiburg.de/oparl/file/sia%7C2024-OR_MU-90%7C1
# filesection_id ba2c50fe-e96b-4406-b684-908b7b418116 file https://ris.freiburg.de/oparl/file/sia%7C2024-OR_MU-90%7C2
# filesection_id 965f8ea0-d78e-44aa-94ff-1486933e19c7 file https://ris.freiburg.de/oparl/file/sia%7C2024-HFA-82%7C1
# filesection_id 67d80719-56fa-4a62-bba9-ba03a79d1b3c file https://ris.freiburg.de/oparl/file/sia%7C2024-HFA-81%7C1
# filesection_id 615b487d-20d1-4f41-8b9a-81e7d54a45c8 file https://ris.freiburg.de/oparl/file/sia%7C2024-HFA-79%7C11
# filesection_id 701a91d8-5e59-4d41-b1f1-6ebe5d516e4a file https://ris.freiburg.de/oparl/file/vla%7C5421101100046%7C2
# filesection_id 4bb7b29a-cf1e-4931-8e79-39366d9b64e3 file https://ris.freiburg.de/oparl/file/vla%7C5420603100086%7C7
# filesection_id 0c8a068a-ad4c-4b54-9886-de905f9dba5d file https://ris.freiburg.de/oparl/file/vla%7C5422603100097%7C3
# filesection_id 928a256a-abc3-4933-80ff-1d8d2d49a6e2 file https://ris.freiburg.de/oparl/file/vla%7C5420103100082%7C3
# filesection_id 429cfa04-ec6d-424b-bc53-d3fb495823cd file https://ris.freiburg.de/oparl/file/vla%7C5420807100145%7C1
# filesection_id 3d52d693-ff30-4f66-b6b2-b069165251e3 file https://ris.freiburg.de/oparl/file/4892411100020
# filesection_id da738dbb-61dd-43e3-be35-da6f27660e79 file https://ris.freiburg.de/oparl/file/4892411100020
# filesection_id c44177de-2e32-4e40-8ae2-acdb3fff67b2 file https://ris.freiburg.de/oparl/file/5002907100005
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownRelationshipTypeWarning} {category: UNRECOGNIZED} {title: The provided relationship type is not in the database.} {description: One of the relationship types in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing relationship type is: MEETING_HAS_INVITATION_FILE)} {position: line: 2, column: 35, offset: 35} for query: '\n        MATCH (file_node:File)<-[:MEETING_HAS_INVITATION_FILE|MEETING_HAS_RESULTS_PROTOCOL_FILE|MEETING_HAS_VERBATIM_PROTOCOL_FILE|MEETING_HAS_AUXILIARY_FILE]-(meeting_node:Meeting)\n        WHERE file_node.id IN $file_ids\n        RETURN file_node.id as file_id, meeting_node, null as paper_node, null as consultation_node, null as agenda_item_node\n        UNION\n        MATCH (file_node:File)<-[:PAPER_HAS_MAIN_FILE|PAPER_HAS_AUXILIARY_FILE]-(paper_node:Paper)-[:PAPER_HAS_CONSULTATION]->(consultation_node:Consultation)<-[:AGENDA_ITEM_HAS_CONSULTATION]-(agenda_item_node:AgendaItem)<-[:MEETING_HAS_AGENDA_ITEM]-(meeting_node:Meeting)\n        WHERE file_node.id IN $file_ids\n        RETURN file_node.id as file_id, meeting_node, paper_node, consultation_node, agenda_item_node\n        '
# https://ris.freiburg.de/oparl/file/sia%7C2024-GR-268%7C1
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-GR-268' type='https://schema.oparl.org/1.0/Meeting' name='8. Sitzung des Gemeinderates (Verabschiedung)' meeting_state='terminiert' cancelled=False start=datetime.datetime(2024, 7, 24, 16, 9) end=datetime.datetime(2024, 7, 24, 18, 20) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-GR-268%7C2
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-GR-268' type='https://schema.oparl.org/1.0/Meeting' name='8. Sitzung des Gemeinderates (Verabschiedung)' meeting_state='terminiert' cancelled=False start=datetime.datetime(2024, 7, 24, 16, 9) end=datetime.datetime(2024, 7, 24, 18, 20) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-GR-269%7C2
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-GR-269' type='https://schema.oparl.org/1.0/Meeting' name='9. Sitzung des Gemeinderates (Konstituierung + Wahl RVSO)' meeting_state='terminiert' cancelled=False start=datetime.datetime(2024, 7, 24, 18, 39) end=datetime.datetime(2024, 7, 24, 19, 29) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-OR_TI-115%7C3
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-OR_TI-115' type='https://schema.oparl.org/1.0/Meeting' name='7. Sitzung des Ortschaftsrates Tiengen (konstituierend)' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2024, 7, 22, 20, 0) end=datetime.datetime(2024, 7, 22, 21, 5) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-GR-267%7C1
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-GR-267' type='https://schema.oparl.org/1.0/Meeting' name='7. Sitzung des Gemeinderates' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2024, 7, 23, 16, 6) end=datetime.datetime(2024, 7, 23, 18, 37) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-HFA-87%7C1
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-HFA-87' type='https://schema.oparl.org/1.0/Meeting' name='8. Sitzung des Haupt- und Finanzausschusses' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2024, 7, 15, 16, 3) end=datetime.datetime(2024, 7, 15, 17, 47) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-OR_LE-112%7C1
# related_meeting id='https://ris.freiburg.de/oparl/meeting/2024-OR_LE-112' type='https://schema.oparl.org/1.0/Meeting' name='### ABGESAGT ### 7. Sitzung des Ortschaftsrates Lehen' meeting_state='terminiert' cancelled=False start=datetime.datetime(2024, 7, 3, 18, 30) end=datetime.datetime(2024, 7, 3, 0, 0) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-OR_MU-94%7C2
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-OR_MU-94' type='https://schema.oparl.org/1.0/Meeting' name='Sitzung des Ortschaftsrates Munzingen' meeting_state='terminiert' cancelled=False start=datetime.datetime(2024, 7, 10, 19, 30) end=datetime.datetime(2024, 7, 10, 20, 29) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-OR_TI-114%7C1
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-OR_TI-114' type='https://schema.oparl.org/1.0/Meeting' name='6. Sitzung des Ortschaftsrates Tiengen' meeting_state='terminiert' cancelled=False start=datetime.datetime(2024, 6, 4, 20, 0) end=datetime.datetime(2024, 6, 4, 21, 28) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-ASW-138%7C2
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-ASW-138' type='https://schema.oparl.org/1.0/Meeting' name='Gemeinsame Sitzung des Ausschusses für Schulen und Weiterbildung und des Kinder- und Jugendhilfeausschusses' meeting_state='terminiert' cancelled=False start=datetime.datetime(2024, 5, 13, 16, 0) end=datetime.datetime(2024, 5, 13, 18, 25) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-OR_TI-113%7C1
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-OR_TI-113' type='https://schema.oparl.org/1.0/Meeting' name='5. Sitzung des Ortschaftsrates Tiengen' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2024, 5, 7, 20, 0) end=datetime.datetime(2024, 5, 7, 22, 0) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-HFA-84%7C1
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-HFA-84' type='https://schema.oparl.org/1.0/Meeting' name='6. Sitzung des Haupt- und Finanzausschusses' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2024, 5, 6, 16, 4) end=datetime.datetime(2024, 5, 6, 18, 33) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-OR_OPF-95%7C1
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-OR_OPF-95' type='https://schema.oparl.org/1.0/Meeting' name='4. Sitzung des Ortschaftsrates Opfingen' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2024, 5, 6, 20, 0) end=datetime.datetime(2024, 5, 6, 22, 50) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-OR_OPF-95%7C5
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-OR_OPF-95' type='https://schema.oparl.org/1.0/Meeting' name='4. Sitzung des Ortschaftsrates Opfingen' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2024, 5, 6, 20, 0) end=datetime.datetime(2024, 5, 6, 22, 50) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-OR_LE-110%7C1
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-OR_LE-110' type='https://schema.oparl.org/1.0/Meeting' name='5. Sitzung des Ortschaftsrates Lehen' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2024, 5, 2, 18, 30) end=datetime.datetime(2024, 5, 2, 21, 17) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-GR-264%7C1
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-GR-264' type='https://schema.oparl.org/1.0/Meeting' name='5. Sitzung des Gemeinderates' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2024, 5, 14, 16, 6) end=datetime.datetime(2024, 5, 14, 18, 50) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-GR-263%7C3
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-GR-263' type='https://schema.oparl.org/1.0/Meeting' name='4. Sitzung des Gemeinderates' meeting_state='terminiert' cancelled=False start=datetime.datetime(2024, 4, 23, 16, 8) end=datetime.datetime(2024, 4, 23, 19, 46) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-UKA-27%7C2
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-UKA-27' type='https://schema.oparl.org/1.0/Meeting' name='2. Sitzung des Ausschusses für Umwelt und Klimaschutz' meeting_state='terminiert' cancelled=False start=datetime.datetime(2024, 3, 18, 16, 0) end=datetime.datetime(2024, 3, 18, 19, 0) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-OR_LE-108%7C1
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-OR_LE-108' type='https://schema.oparl.org/1.0/Meeting' name='3. Sitzung des Ortschaftsrates Lehen' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2024, 3, 13, 19, 30) end=datetime.datetime(2024, 3, 13, 21, 9) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-AWW-8%7C3
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-AWW-8' type='https://schema.oparl.org/1.0/Meeting' name='1. Sitzung des Ausschusses für Wirtschaft und Wissenschaft' meeting_state='terminiert' cancelled=False start=datetime.datetime(2024, 4, 8, 16, 0) end=datetime.datetime(2024, 4, 8, 19, 0) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-HFA-82%7C1
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-HFA-82' type='https://schema.oparl.org/1.0/Meeting' name='4. Sitzung des Haupt- und Finanzausschusses' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2024, 3, 11, 16, 1) end=datetime.datetime(2024, 3, 11, 17, 23) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-GR-262%7C1
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-GR-262' type='https://schema.oparl.org/1.0/Meeting' name='3. Sitzung des Gemeinderates' meeting_state='terminiert' cancelled=False start=datetime.datetime(2024, 3, 19, 16, 4) end=datetime.datetime(2024, 3, 19, 19, 4) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-GR-262%7C3
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-GR-262' type='https://schema.oparl.org/1.0/Meeting' name='3. Sitzung des Gemeinderates' meeting_state='terminiert' cancelled=False start=datetime.datetime(2024, 3, 19, 16, 4) end=datetime.datetime(2024, 3, 19, 19, 4) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-OR_MU-90%7C1
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-OR_MU-90' type='https://schema.oparl.org/1.0/Meeting' name='Sitzung des Ortschaftsrates Munzingen' meeting_state='terminiert' cancelled=False start=datetime.datetime(2024, 3, 6, 19, 30) end=datetime.datetime(2024, 3, 6, 21, 56) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-OR_MU-90%7C2
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-OR_MU-90' type='https://schema.oparl.org/1.0/Meeting' name='Sitzung des Ortschaftsrates Munzingen' meeting_state='terminiert' cancelled=False start=datetime.datetime(2024, 3, 6, 19, 30) end=datetime.datetime(2024, 3, 6, 21, 56) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-HFA-81%7C1
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-HFA-81' type='https://schema.oparl.org/1.0/Meeting' name='3. Sitzung des Haupt- und Finanzausschusses' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2024, 2, 19, 16, 5) end=datetime.datetime(2024, 2, 19, 19, 9) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-HFA-79%7C11
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-HFA-79' type='https://schema.oparl.org/1.0/Meeting' name='1. Sitzung des Haupt- und Finanzausschusses (Sondersitzung zum Beteiligungsbericht)' meeting_state='terminiert' cancelled=False start=datetime.datetime(2024, 1, 15, 16, 6) end=datetime.datetime(2024, 1, 15, 18, 25) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/4892411100020
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-HFA-52' type='https://schema.oparl.org/1.0/Meeting' name='4. Sitzung des Haupt- und Finanzausschusses' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 3, 28, 16, 6) end=datetime.datetime(2022, 3, 28, 19, 8) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/4892411100020' type='https://schema.oparl.org/1.0/Paper' body=None name='Abschlussbericht zum Beteiligungshaushalt 2021/2022 und Verfahren für den Beteiligungshaushalt 2023/2024' reference='G-22/021' date=datetime.datetime(2022, 3, 18, 0, 0) paper_type='BESCHLUSS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/30505' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='beratend' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2022-HFA-52%7C4892411100020%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='3' order=None name='Abschlussbericht zum Beteiligungshaushalt 2021/2022 und Verfahren für den Beteiligungshaushalt 2023/2024' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/4892411100020
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-GR-234' type='https://schema.oparl.org/1.0/Meeting' name='3. Sitzung des Gemeinderates' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 4, 5, 16, 11) end=datetime.datetime(2022, 4, 5, 20, 8) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/4892411100020' type='https://schema.oparl.org/1.0/Paper' body=None name='Abschlussbericht zum Beteiligungshaushalt 2021/2022 und Verfahren für den Beteiligungshaushalt 2023/2024' reference='G-22/021' date=datetime.datetime(2022, 3, 18, 0, 0) paper_type='BESCHLUSS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/30504' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='beschließend' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2022-GR-234%7C4892411100020%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='9' order=None name='Abschlussbericht zum Beteiligungshaushalt 2021/2022 und Verfahren für den Beteiligungshaushalt 2023/2024' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/5002907100005
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-SO-191' type='https://schema.oparl.org/1.0/Meeting' name='4. Sitzung des Sozialausschusses' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 9, 29, 16, 0) end=datetime.datetime(2022, 9, 29, 19, 35) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/5002907100005' type='https://schema.oparl.org/1.0/Paper' body=None name="Sachstand zum Antrag vom 07.06.2022 nach § 34 GemO von 'Die Grünen im Freiburger Gemeinderat' zur Einrichtung eines Drogenkonsumraums in Freiburg" reference='SO-22/006' date=datetime.datetime(2022, 9, 21, 0, 0) paper_type='INFORMATIONS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/31027' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='zur Information' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2022-SO-191%7C5002907100005%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='5' order=None name="Sachstand zum Antrag vom 07.06.2022 nach § 34 GemO von 'Die Grünen im Freiburger Gemeinderat' zur Einrichtung eines Drogenkonsumraums in Freiburg" public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/vla%7C5420807100145%7C1
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-GR-267' type='https://schema.oparl.org/1.0/Meeting' name='7. Sitzung des Gemeinderates' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2024, 7, 23, 16, 6) end=datetime.datetime(2024, 7, 23, 18, 37) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/5420807100145' type='https://schema.oparl.org/1.0/Paper' body=None name='Änderung von Ziffer 5 des Redaktionsstatuts für das Amtsblatt der Stadt Freiburg - Aufteilung der Textumfänge für Beiträge der Fraktionen, Gruppierungen und Einzelstadträt_innen' reference='G-24/142' date=datetime.datetime(2024, 7, 12, 0, 0) paper_type='BESCHLUSS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/33868' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='beschließend' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2024-GR-267%7C5420807100145%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='5' order=None name='Änderung von Ziffer 5 des Redaktionsstatuts für das Amtsblatt der Stadt Freiburg - Aufteilung der Textumfänge für Beiträge der Fraktionen, Gruppierungen und Einzelstadträt_innen' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/vla%7C5422603100097%7C3
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-GR-264' type='https://schema.oparl.org/1.0/Meeting' name='5. Sitzung des Gemeinderates' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2024, 5, 14, 16, 6) end=datetime.datetime(2024, 5, 14, 18, 50) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/5422603100097' type='https://schema.oparl.org/1.0/Paper' body=None name='Änderung der Satzung über die Finanzierung des Aufwands der Fraktionen, Gruppierungen und fraktionslosen Mitglieder des Gemeinderats: \r\n- Umstellungszeitpunkt des Personalkostenbudgets nach Wahlen (interfraktioneller Antrag nach § 34 GemO der Fraktionen JUPI, ESfa und FDP/BfF vom 06.03.2024)\r\n- redaktionelle Änderungen' reference='G-24/094' date=datetime.datetime(2024, 4, 26, 0, 0) paper_type='BESCHLUSS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/33249' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='beschließend' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2024-GR-264%7C5422603100097%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='13' order=None name='Änderung der Satzung über die Finanzierung des Aufwands der Fraktionen, Gruppierungen und fraktionslosen Mitglieder des Gemeinderats: \r\n- Umstellungszeitpunkt des Personalkostenbudgets nach Wahlen (interfraktioneller Antrag nach § 34 GemO der Fraktionen JUPI, ESfa und FDP/BfF vom 06.03.2024)\r\n- redaktionelle Änderungen' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/vla%7C5422603100097%7C3
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-HFA-84' type='https://schema.oparl.org/1.0/Meeting' name='6. Sitzung des Haupt- und Finanzausschusses' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2024, 5, 6, 16, 4) end=datetime.datetime(2024, 5, 6, 18, 33) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/5422603100097' type='https://schema.oparl.org/1.0/Paper' body=None name='Änderung der Satzung über die Finanzierung des Aufwands der Fraktionen, Gruppierungen und fraktionslosen Mitglieder des Gemeinderats: \r\n- Umstellungszeitpunkt des Personalkostenbudgets nach Wahlen (interfraktioneller Antrag nach § 34 GemO der Fraktionen JUPI, ESfa und FDP/BfF vom 06.03.2024)\r\n- redaktionelle Änderungen' reference='G-24/094' date=datetime.datetime(2024, 4, 26, 0, 0) paper_type='BESCHLUSS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/33250' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='beratend' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2024-HFA-84%7C5422603100097%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='3' order=None name='Änderung der Satzung über die Finanzierung des Aufwands der Fraktionen, Gruppierungen und fraktionslosen Mitglieder des Gemeinderats: \r\n- Umstellungszeitpunkt des Personalkostenbudgets nach Wahlen (interfraktioneller Antrag nach § 34 GemO der Fraktionen JUPI, ESfa und FDP/BfF vom 06.03.2024)\r\n- redaktionelle Änderungen' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/vla%7C5420103100082%7C3
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-HFA-87' type='https://schema.oparl.org/1.0/Meeting' name='8. Sitzung des Haupt- und Finanzausschusses' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2024, 7, 15, 16, 3) end=datetime.datetime(2024, 7, 15, 17, 47) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/5420103100082' type='https://schema.oparl.org/1.0/Paper' body=None name='Förderung von Kindertagespflege in Freiburg:\r\nNeufassung der Richtlinien zur Förderung von Kindern in Kindertagespflege\r\n(interfraktioneller Antrag nach § 34 Gemeindeordnung von B90/DG und CDU vom 11.01.2024)' reference='G-24/080' date=datetime.datetime(2024, 6, 19, 0, 0) paper_type='BESCHLUSS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/33888' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='beratend' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2024-HFA-87%7C5420103100082%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='5' order=None name='Förderung von Kindertagespflege in Freiburg:\r\nNeufassung der Richtlinien zur Förderung von Kindern in Kindertagespflege\r\n(interfraktioneller Antrag nach § 34 Gemeindeordnung von B90/DG und CDU vom 11.01.2024)' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/vla%7C5420103100082%7C3
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-GR-267' type='https://schema.oparl.org/1.0/Meeting' name='7. Sitzung des Gemeinderates' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2024, 7, 23, 16, 6) end=datetime.datetime(2024, 7, 23, 18, 37) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/5420103100082' type='https://schema.oparl.org/1.0/Paper' body=None name='Förderung von Kindertagespflege in Freiburg:\r\nNeufassung der Richtlinien zur Förderung von Kindern in Kindertagespflege\r\n(interfraktioneller Antrag nach § 34 Gemeindeordnung von B90/DG und CDU vom 11.01.2024)' reference='G-24/080' date=datetime.datetime(2024, 6, 19, 0, 0) paper_type='BESCHLUSS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/33889' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='beschließend' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2024-GR-267%7C5420103100082%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='8' order=None name='Förderung von Kindertagespflege in Freiburg:\r\nNeufassung der Richtlinien zur Förderung von Kindern in Kindertagespflege\r\n(interfraktioneller Antrag nach § 34 Gemeindeordnung von B90/DG und CDU vom 11.01.2024)' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/vla%7C5420103100082%7C3
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-KJHA-144' type='https://schema.oparl.org/1.0/Meeting' name='3. Sitzung des Kinder- und Jugendhilfeausschusses' meeting_state='terminiert' cancelled=False start=datetime.datetime(2024, 6, 27, 16, 0) end=datetime.datetime(2024, 6, 27, 19, 0) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/5420103100082' type='https://schema.oparl.org/1.0/Paper' body=None name='Förderung von Kindertagespflege in Freiburg:\r\nNeufassung der Richtlinien zur Förderung von Kindern in Kindertagespflege\r\n(interfraktioneller Antrag nach § 34 Gemeindeordnung von B90/DG und CDU vom 11.01.2024)' reference='G-24/080' date=datetime.datetime(2024, 6, 19, 0, 0) paper_type='BESCHLUSS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/33890' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='beratend' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2024-KJHA-144%7C5420103100082%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='2' order=None name='Förderung von Kindertagespflege in Freiburg:\r\nNeufassung der Richtlinien zur Förderung von Kindern in Kindertagespflege\r\n(interfraktioneller Antrag nach § 34 Gemeindeordnung von B90/DG und CDU vom 11.01.2024)' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/vla%7C5421101100046%7C2
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-The-80' type='https://schema.oparl.org/1.0/Meeting' name='2. Sitzung des Theaterausschusses' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2024, 5, 2, 16, 0) end=datetime.datetime(2024, 5, 2, 19, 0) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/5421101100046' type='https://schema.oparl.org/1.0/Paper' body=None name='Neufassung der Satzung über die Führung des Theater Freiburg als Eigenbetrieb' reference='G-24/047' date=datetime.datetime(2024, 4, 24, 0, 0) paper_type='BESCHLUSS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/33204' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='beratend' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2024-The-80%7C5421101100046%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='3' order=None name='Neufassung der Satzung über die Führung des Theater Freiburg als Eigenbetrieb' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/vla%7C5421101100046%7C2
# ...
# id='879fdc15-d6e9-4d85-a188-170b48d6eb41' step=<HitStep.RELATED_DATA_GATHERED: 'RELATED_DATA_GATHERED'> file_chunk=FileChunk(id='44a77293-7af5-4323-9678-5a496d2f3a17', file_section_id=None, text='- Drucksache G-24/035 - beschließend\n(bereits zugestellt)\n11. 1. Finanzbericht 2024\n- Drucksache G-24/116 - zur Information\n(bereits zugestellt)\nJahresabschlüsse 2023 der städtischen Mehrheitsbeteiligungen, Wirtschaftsplanänderungen 2024\n- Drucksache G-24/092 - beschließend\n(bereits zugestellt)\n13. Entlastung der Aufsichtsrät_innen der städtischen Mehrheitsbeiligungen für das Jahr 2023\n- Drucksache G-24/110 - beschließend  \n- 4 -', created_at=datetime.datetime(2024, 9, 8, 20, 3, 1, 363085), modified_at=datetime.datetime(2024, 9, 8, 20, 3, 1, 363086)) file_section=FileSection(id='fd9d62ae-9c18-48d3-92f9-46db8a542cf3', file_id=None, text='Das Bürgermeisteramt der Stadt Freiburg im Breisgau - Dezernat I -\nFreiburg i. Br., 12.07.2024 Tel.: 0761/201-1110 Herr Knobloch\n\n7. Sitzung des Gemeinderates\n\nMitglieder des Gemeinderates\n\nIch lade zu der am\n\nDienstag, 23. Juli 2024, 16:00 Uhr\n\nim Neuen Ratssaal des Rathauses stattfindenden Sitzung des Gemeinderates ein.\n\nT a g e s o r d n u n g\n\nÖffentlicher Teil\n\n1. 50 Jahre Eingemeindung der Ortschaften Ebnet und Kappel in die Stadt Freiburg\n\n2. Beschlussfassung zum weiteren Verfahren: Interfraktioneller Antrag "Aktueller Stand der Umsetzung des Fahrplans für schulische Inklusion"\n- Antrag - beschließend\n\n3. Beschlussfassung zum weiteren Verfahren: Interfraktioneller Antrag "Unterstützung von Amateur-Spitzensportvereinen"\n- Antrag - beschließend\n\n- 2 -\n\n4. Stellungnahme der Stadt Freiburg zur Offenlage des Planentwurfs "Teilfortschreibung "Windenergie" und Teilfortschreibung "Solarenergie" des Regionalplans Südlicher Oberrhein"\n- Drucksache G-24/131 - beschließend\n(bereits zugestellt)\n\n5. Änderung von Ziffer 5 des Redaktionsstatuts für das Amtsblatt der Stadt Freiburg - Aufteilung der Textumfänge für Beiträge der Fraktionen, Gruppierungen und Einzelstadträt_innen\n- Drucksache G-24/142 - beschließend\n\n6. Abwicklung der Vergabe des Anwesens Basler Straße 2, Grundstück Flst.Nr. 4203 u. a. an das Studierendenwerk Freiburg\n- Drucksache G-24/124 - beschließend\n(bereits zugestellt)\n\n7. I. Information zum Rechnungsergebnis in der Kinder- und Jugendhilfe für das Haushaltsjahr 2023\nII. Fallzahlen- und Kostenentwicklung in der Kinder- und Jugendhilfe im Jahr 2024\n- Drucksache G-24/098 - zur Information\n(bereits zugestellt)\n\n8. Förderung von Kindertagespflege in Freiburg: Neufassung der Richtlinien zur Förderung von Kindern in Kindertagespflege (interfraktioneller Antrag nach § 34 Gemeindeordnung von B90/DG und CDU vom 11.01.2024)\n- Drucksache G-24/080 - beschließend\n(bereits zugestellt)\n\n- 3 -\nÄnderung des Wirtschaftsplans des Eigenbetrieb Theater Freiburg für die Geschäftsjahre 2023/2024 und 2024/2025\n- Drucksache G-24/046 - beschließend\n(bereits zugestellt)\n10. Aufhebung der Förderkriterien für die Projektförderung für Kulturelle Bildung, Interkulturelle Kunst und Kultur und Stadtteilkultur (Kulturkonzept Freiburg) und künftiges Förderverfahren für Projekte der Kulturellen Teilhabe\n- Drucksache G-24/035 - beschließend\n(bereits zugestellt)\n11. 1. Finanzbericht 2024\n- Drucksache G-24/116 - zur Information\n(bereits zugestellt)\nJahresabschlüsse 2023 der städtischen Mehrheitsbeteiligungen, Wirtschaftsplanänderungen 2024\n- Drucksache G-24/092 - beschließend\n(bereits zugestellt)\n13. Entlastung der Aufsichtsrät_innen der städtischen Mehrheitsbeiligungen für das Jahr 2023\n- Drucksache G-24/110 - beschließend\n\n- 4 -\n14. Verlängerung der Erbbaurechte der GAGFAH GmbH, Bochum an den stadteigenen Grundstücken - Flst.Nr. 2867, Sautierstraße 64, 66 und Stefan-Meier-Straße 86, 88, 90, 92, 94, 96,\nFlst.Nr. 2868, Rennweg 19, 21 und Stefan-Meier-Straße 80, 82, 84 - Flst.Nr. 14395/89, Dimmlerstraße 1, 1a - Flst.Nr. 14395/85, Jahnstraße 9, 11, 13, 15 - Fl ...
# id='0202f5e7-d82b-47ef-bd20-091659b1cd7e' step=<HitStep.RELATED_DATA_GATHERED: 'RELATED_DATA_GATHERED'> file_chunk=FileChunk(id='8d486826-5fe6-46c6-aa5c-3e6f2c3ecc48', file_section_id=None, text='(bereits zugestellt)  \n- 4 -\n14. Kindertagesstättenbedarfsplanung für das Kindergartenjahr 2024/2025 und Aufhebung der Satzung über die Umsetzung des Anspruchs auf den Besuch eines Kindergartens\n- Drucksache G-24/084 - beschließend\n(bereits zugestellt)\n15. Einrichtung eines Ganztagsbetriebs in gebundener Form an der Johannes-Schwartz-Schule - Grundsatzbeschluss\n- Drucksache G-24/011 - beschließend\n(bereits zugestellt)', created_at=datetime.datetime(2024, 9, 8, 20, 2, 25, 425391), modified_at=datetime.datetime(2024, 9, 8, 20, 2, 25, 425393)) file_section=FileSection(id='f317e770-9acf-4ee5-b192-ee8b8bf0eca9', file_id=None, text='Das Bürgermeisteramt der Stadt Freiburg im Breisgau - Dezernat I -\nFreiburg i. Br., 03.05.2024 Tel.: 0761/201-1110 Herr Knobloch\n\n5. Sitzung des Gemeinderates\n\nMitglieder des Gemeinderates\n\nIch lade zu der am\n\nDienstag, 14. Mai 2024, 16:00 Uhr\n\nim Neuen Ratssaal des Rathauses stattfindenden Sitzung des Gemeinderates ein.\n\nT a g e s o r d n u n g\n\nÖffentlicher Teil\n\n1. Beschlussfassung zum weiteren Verfahren: Antrag von Bündnis 90/DIE GRÜNEN "Sozialticket für Wohngeldbeziehende"\n- Antrag - beschließend\n\n2. Beschlussfassung zum weiteren Verfahren: Antrag von Eine Stadt für Alle "Bearbeitung von Wohngeldanträgen und Gewährung von Annex-Leistungen"\n- Antrag - beschließend\n\n3. Jahresabschluss 2022 1. Schlussbericht des Rechnungsprüfungsamtes 2. Jahresabschluss 2022\n- Drucksache G-24/074 - beschließend\n\n(bereits zugestellt)\n\n- 2 -\n\n4. Informationen zum Jahresergebnis 2023\n- Wesentliche Ergebnisse des Haushaltsjahres 2023\n- Genehmigung einer überplanmäßigen Aufwendung\n\n- Drucksache G-24/075 - \nbeschließend\n(bereits zugestellt)\n\n5. Jahresabschlüsse 2023 der ASF GmbH, der ASF Solar Verwaltungs-GmbH und der ASF Solar GmbH & Co. KG\n\n- Drucksache G-24/079 - \nbeschließend\n(bereits zugestellt)\n\n6. Entlastung der Aufsichtsrät_innen der ASF GmbH und mittelbar der ASF Solar Verwaltungs-GmbH und der ASF Solar GmbH & Co. KG für das Jahr 2023\n\n- Drucksache G-24/088 - \nbeschließend\n\n7. Fortschreibung des Tourismuskonzepts für die Stadt Freiburg: Tourismuskonzept Freiburg 2024 (TK2)\n\n- Drucksache G-24/064 - \nbeschließend\n(bereits zugestellt)\n\n8. Änderung der Richtlinien über den Weihnachtsmarkt in der Stadt Freiburg i. Br.\n\n- Drucksache G-24/049 - \nbeschließend\n(bereits zugestellt)\n\n- 3 -\n9. Anpassung Platzentgelte Weihnachtsmarkt Freiburg sowie Dauer des Weihnachtsmarktes unter Einbeziehung des Totensonntags/Ewigkeits- sonntags\n- Drucksache G-24/083 - beschließend\n(bereits zugestellt)\n10. Standortentscheidung für die Errichtung eines Ruhewaldes im Stern- waldeck/Wiehre\n- Drucksache G-24/077 - beschließend\n(bereits zugestellt)\n11. Änderung der Stadionverordnung und Regelung zu fantypischem Verhalten\n- Drucksache G-24/037 - beschließend\n(bereits zugestellt)\n12. Erlass einer neuen Feuerwehr-Kostensatzung zum 01.06.2024 und Neufassung der Feuerwehrsatzung zum 01.01.2025\n- Drucksache G-24/093 - beschließend\n(bereits zugestellt)\n13. Änderung der Satzung über die Finanzierung des Aufwands der Fraktionen, Gruppierungen und fraktionslosen Mitglieder des Gemeinderats: - Umstellungszeitpunkt des Personalkostenbudgets nach Wahlen (inter- fraktioneller Antrag nach § 34 GemO der Fraktionen JUPI, ESfa und FDP/BfF vom 06.03.2024) - redaktionelle Änderungen\n- Drucksache G-24/094 - beschließend\n(bereits zugestellt)\n\n- 4 -\n14. Kindertagesstättenbedarfsplanung für das Kindergartenjahr 2024/2025 und Aufhebung der Satzung über die Umsetzung des Anspruchs auf den Besuch eines Kindergartens\n- Drucksache G-24/084 - beschließend\n(bereits zugestellt)\n15. Einrichtung eines Ganztagsbetriebs in gebundener Form an der Johannes-Schwartz-Schule - Grundsatzbeschluss\n- Drucksach ...
# id='622fbb8f-0e25-4653-9f6e-ec1929bfd4f1' step=<HitStep.RELATED_DATA_GATHERED: 'RELATED_DATA_GATHERED'> file_chunk=FileChunk(id='59cb8c23-d378-4528-b76e-1c3c9318aa97', file_section_id=None, text='Protokoll der OR-Sitzung vom 10.07.2024  \nAnlage Beschlussantrag zu TOP 2, Ortschaftsrat Munzingen, 10.07.2024, Drucksache G-24/131 Stellungnahme der Stadt Freiburg zur Offenlage des Pianentwurfs „Teilfortschreibung „Windenergie“ und Teilfortschreibung „Solarenenergie“ des Regionalplans Südlicher Oberrhein“  \nDer Ortschaftsrat Munzingen bittet die Verwaltung, in ihrer Stellungnahme auf die Rücknahme der Flächen F-74 und F-75 hinzuwirken.', created_at=datetime.datetime(2024, 9, 8, 20, 13, 7, 941168), modified_at=datetime.datetime(2024, 9, 8, 20, 13, 7, 941168)) file_section=FileSection(id='daa4f31b-e577-4f71-a7b0-6f3e228845c3', file_id=None, text='Ergebnismitteilung über die öffentliche Sitzung des Ortschaftsrates Munzingen vom 10.07.2024 im Bürgersaal in Munzingen in Freiburg im Breisgau\n\nOrtschaftsrätinnen und Ortschaftsräte mit Stimmrecht:\nAnwesend: 11 von 12 Rät_innen\nChristian Schildecker, Ortsvorsteher\nKlaus Riemann\nUlrich Schopp\nPhilipp Schillinger\nClemens Lang\nElisabetha Gräfin von Kageneck\nWolfgang Schmid\nLiliane Moser\nKunigunde Stifel\nKatja Weber\nKatharina Wirth\n\nEs fehlten: Toni Luhr entschuldigt\n\nVon der Verwaltung: - Carola Bernath, Schriftführerin\n\nZur Sitzung des Ortschaftsrates Munzingen wurde form- und fristgerecht eingeladen. Bei Eröffnung der Sitzung um 19:30 Uhr durch OV Schildecker war das Plenum beschlussfähig. (Die Tagesordnung siehe Anlage 1).\n\nTOP 1 Fragen und Anregungen aus der Bürgerschaft\na) Ein Bürger erkundigt sich, wie die Nutzung von öffentlichen Gebäuden in Munzingen im Bereich der Photovoltaik voran gebracht werden kann.\nAntwort: In 2023 entstand die Idee, hierfür eine Genossenschaft oder eine Gesellschaft bürgerlichen Rechts zu gründen. Es hatten sich auch bereits interessierte Bürger_innen gemeldet. Allerdings gibt es bereits Genossenschaften, die in diesem Bereich tätig sind und evtl. Interesse haben, hier einzusteigen. Das Thema wird seitens der Verwaltung nochmals reaktiviert.\n\nWortmeldungen: Ein Bürger OV Schildecker\n\nTOP 2 Stellungnahme der Stadt Freiburg zur Offenlage des Planentwurfs „Teilfortschreibung „Windenergie“ und Teilfortschreibung „Solarenenergie“ des Regionalplans Südlicher Oberrhein“ Beschlussvorlage G-24/131\nBeschluss: Der Ortschaftsrat Munzingen hat dem Beschlussantrag (Anlage) und der Beschlussvorlage einstimmig zugestimmt und verweist in diesem Zusammenhang auf seine Stellungnahme, siehe Anlage\nVortrag: Markus Liesen, Stadtplanungsamt\nWortmeldungen: OV Schildecker ORätin Weber ORätin von Kageneck\n\nHerr Liesen\nOR Riemann\nOR Lang\nORätin Stifel\nOR Schmid\nORätin Moser\n\nTOP 3 Verschiedenes\na) Beim Rossbächle gibt es aktuell viele Schnaken.\nWortmeldungen: ORätin Stifel ORätin von Kageneck OR Lang OV Schildecker\n\nb) OR Riemann hat einen Leserbrief an die Badische Zeitung geschrieben.\nWortmeldungen: OR Riemann ORätin von Kageneck OV Schildecker ORätin Stifel\n\nc) Der Förderverein Kinder-und Jugendarbeit Tuniberg e.V. ist auf der Suche nach neuen Ehrenamtlichen.\nWortmeldungen: OR Schmid ORätin Stifel\n\nOV Schildecker schließt um 20:29 Uhr die öffentliche Sitzung.\n\nHerr Schildecker, Ortsvorsteher als Vorsitzender  Frau Bernath als Schriftführerin  Ortschaftsrat  Orts\n\nProtokoll der OR-Sitzung vom 10.07.2024\n\nAnlage Beschlussantrag zu TOP 2, Ortschaftsrat Munzingen, 10.07.2024, Drucksache G-24/131 Stellungnahme der Stadt Freiburg zur Offenlage des Pianentwurfs „Teilfortschreibung „Windenergie“ und Teilfortschreibung „Solarenenergie“ des Regionalplans Südlicher Oberrhein“\n\nDer Ortschaftsrat Munzingen bittet die Verwaltung, in ihrer Stellungnahme auf die Rücknahme der Flächen F-74 und F-75 hinzuwirken.\n\nDer Ortschaftsrat Munzingen weist auf den Widerspruch unter 4.2 der Stellungnahme hin: im ersten Spiegelpunkt wird zutreffend ausge ...
# 'In der Sitzung am 25.07.2024 werden voraussichtlich die Verabschiedungen der ausscheidenden Ortsvorsteher_innen und des Gemeinderats der Amtsperiode 2019 - 2024 behandelt. Zudem sind Bekanntgaben und Aktuelles auf der Tagesordnung. Die konstituierende Sitzung des neuen Gemeinderates für die Amtsperiode 2024 - 2029 folgt im Anschluss. \n\nAccess URL: https://ris.freiburg.de/documents.php?id=69&inline=1&document_type_id=11&meeting_attachment_id=ni_2024-GR-268%7C20240712125630-0_2024-GR-268_1.pdf'

# %%
from langchain import hub
from langchain_openai import ChatOpenAI

us_client = Client(api_key="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", api_url="https://api.smith.langchain.com")


# Grade prompt 
grade_prompt_answer_accuracy = prompt = us_client.pull_prompt("langchain-ai/rag-answer-vs-reference",)

def answer_evaluator(run, example) -> dict:
    """
    A simple evaluator for RAG answer accuracy
    """
    
    # Get summary
    input_question = example.inputs["question"]
    reference = example.outputs["answer"]
    prediction = run.outputs["output"]  # Changed from "answer" to "output"

    # LLM grader
    llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

    # Structured prompt
    
    answer_grader = grade_prompt_answer_accuracy | llm

    # Get score
    score = answer_grader.invoke({"question": input_question,
                                  "correct_answer": reference,
                                  "student_answer": prediction})
    score = score["Score"]

    return {"key": "answer_score", "score": score}

# %%
result = evaluate( 
    lambda x:  chain.invoke(x["question"]),
    data=samples,  # Recreated dataset for this experiment
    evaluators=[answer_evaluator],
    experiment_prefix="example",  # The name of the experiment
    metadata={
        "version": "1.0.0",
        "revision_id": "beta"
    },
    client=client   
)
# Out:
# View the evaluation results for experiment: 'example-ed91b322' at:
# https://eu.smith.langchain.com/o/f2baf51a-5907-4625-b2ab-a98883dd8671/datasets/53d8174c-38ca-41fd-9dc8-faa6ef72478a/compare?selectedSessions=089e3a28-6246-4d7f-b181-d5ed297af052
# 0it [00:00, ?it/s]
# filesection_id 82132830-3e1b-4294-9e09-f216ba0c32da file https://ris.freiburg.de/oparl/file/sia%7C2024-GR-262%7C3
# filesection_id 47658b3f-5c01-4776-ba9a-04adbfc20c75 file https://ris.freiburg.de/oparl/file/sia%7C2024-KA-156%7C1
# filesection_id 436714a0-80f1-45c4-95f8-88870ef10f4b file https://ris.freiburg.de/oparl/file/sia%7C2024-OR_OPF-92%7C3
# filesection_id 33388212-f1d7-4567-b9ee-7aa40fe79b02 file https://ris.freiburg.de/oparl/file/sia%7C2023-BehB-14%7C5
# filesection_id d9d1d2e8-37f6-4886-ab91-ca8f28f7ef56 file https://ris.freiburg.de/oparl/file/sia%7C2023-BehB-14%7C8
# filesection_id 8c836e0c-f930-4f10-aca4-876b76e112a2 file https://ris.freiburg.de/oparl/file/sia%7C2021-OR_MU-63%7C2
# filesection_id f6e98a07-92e4-4df4-aad0-ed6d1d40e218 file https://ris.freiburg.de/oparl/file/sia%7C2021-OR_MU-58%7C2
# filesection_id 2714a009-bd42-449e-8bb8-8740a5829b6e file https://ris.freiburg.de/oparl/file/vla%7C5160109100198%7C3
# filesection_id d8b71126-7b19-4856-88bc-c721e13040c0 file https://ris.freiburg.de/oparl/file/vla%7C5421801100054%7C3
# filesection_id b39b3f41-26b8-4757-93e3-90ed18c9a70d file https://ris.freiburg.de/oparl/file/vla%7C5420801100039%7C3
# filesection_id db1e1685-cd80-40f2-9fb7-5a3bf9e547ad file https://ris.freiburg.de/oparl/file/5160409100203
# filesection_id b8ae2b9a-cd9e-42b2-8474-c5717d5293df file https://ris.freiburg.de/oparl/file/4891104100112
# filesection_id 2325e00b-94cb-4d8d-b1ea-82695963fe8c file https://ris.freiburg.de/oparl/file/4891104100112
# filesection_id 5c912092-d4ef-4e8b-9b3f-afaee4ad4241 file https://ris.freiburg.de/oparl/file/4892308100197
# filesection_id ec2249c9-f1a7-490e-a552-81b50b002d06 file https://ris.freiburg.de/oparl/file/4892504100117
# filesection_id 8c66eabf-d294-4cf8-ac63-fab073c0e5d2 file https://ris.freiburg.de/oparl/file/5000405100004
# filesection_id 94448b73-d8fd-48d6-841e-f3cf53922c12 file https://ris.freiburg.de/oparl/file/5161210100002
# https://ris.freiburg.de/oparl/file/sia%7C2021-OR_MU-63%7C2
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2021-OR_MU-63' type='https://schema.oparl.org/1.0/Meeting' name='Sitzung des Ortschaftsrates Munzingen' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2021, 11, 10, 19, 30) end=datetime.datetime(2021, 11, 10, 21, 35) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2021-OR_MU-58%7C2
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2021-OR_MU-58' type='https://schema.oparl.org/1.0/Meeting' name='Sitzung des Ortschaftsrates Munzingen' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2021, 5, 12, 19, 30) end=datetime.datetime(2021, 5, 12, 21, 50) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2023-BehB-14%7C5
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2023-BehB-14' type='https://schema.oparl.org/1.0/Meeting' name='4. Sitzung des Beirates für Menschen mit Behinderung' meeting_state='terminiert' cancelled=False start=datetime.datetime(2023, 11, 21, 16, 0) end=datetime.datetime(2023, 11, 21, 18, 15) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2023-BehB-14%7C8
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2023-BehB-14' type='https://schema.oparl.org/1.0/Meeting' name='4. Sitzung des Beirates für Menschen mit Behinderung' meeting_state='terminiert' cancelled=False start=datetime.datetime(2023, 11, 21, 16, 0) end=datetime.datetime(2023, 11, 21, 18, 15) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-GR-262%7C3
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-GR-262' type='https://schema.oparl.org/1.0/Meeting' name='3. Sitzung des Gemeinderates' meeting_state='terminiert' cancelled=False start=datetime.datetime(2024, 3, 19, 16, 4) end=datetime.datetime(2024, 3, 19, 19, 4) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-KA-156%7C1
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-KA-156' type='https://schema.oparl.org/1.0/Meeting' name='1. Sitzung des Kulturausschusses' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2024, 2, 22, 15, 45) end=datetime.datetime(2024, 2, 22, 19, 0) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/sia%7C2024-OR_OPF-92%7C3
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2024-OR_OPF-92' type='https://schema.oparl.org/1.0/Meeting' name='2. Sitzung des Ortschaftsrates Opfingen' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2024, 2, 5, 20, 0) end=datetime.datetime(2024, 2, 5, 22, 0) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper None
# related_consultation None
# related_agenda_item None
# https://ris.freiburg.de/oparl/file/4891104100112
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-GR-235' type='https://schema.oparl.org/1.0/Meeting' name='4. Sitzung des Gemeinderates' meeting_state='terminiert' cancelled=False start=datetime.datetime(2022, 5, 17, 16, 9) end=datetime.datetime(2022, 5, 17, 19, 22) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/4891104100112' type='https://schema.oparl.org/1.0/Paper' body=None name='Implementierung von präventiver Quartiersarbeit im Zusammenhang mit den Baumaßnahmen im Bereich Metzgergrün (interfraktioneller Antrag vom 23.03.2022)' reference='G-22/111' date=datetime.datetime(2022, 4, 29, 0, 0) paper_type='BESCHLUSS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/30611' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='beschließend' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2022-GR-235%7C4891104100112%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='9' order=None name='Implementierung von präventiver Quartiersarbeit im Zusammenhang mit den Baumaßnahmen im Bereich Metzgergrün (interfraktioneller Antrag vom 23.03.2022)' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/4891104100112
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-HFA-53' type='https://schema.oparl.org/1.0/Meeting' name='5. Sitzung des Haupt- und Finanzausschusses' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 5, 9, 16, 7) end=datetime.datetime(2022, 5, 9, 19, 22) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/4891104100112' type='https://schema.oparl.org/1.0/Paper' body=None name='Implementierung von präventiver Quartiersarbeit im Zusammenhang mit den Baumaßnahmen im Bereich Metzgergrün (interfraktioneller Antrag vom 23.03.2022)' reference='G-22/111' date=datetime.datetime(2022, 4, 29, 0, 0) paper_type='BESCHLUSS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/30612' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='beratend' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2022-HFA-53%7C4891104100112%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='6' order=None name='Implementierung von präventiver Quartiersarbeit im Zusammenhang mit den Baumaßnahmen im Bereich Metzgergrün (interfraktioneller Antrag vom 23.03.2022)' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/5000405100004
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-SO-190' type='https://schema.oparl.org/1.0/Meeting' name='3. Sitzung des Sozialausschusses' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 6, 23, 16, 0) end=datetime.datetime(2022, 6, 23, 19, 45) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/5000405100004' type='https://schema.oparl.org/1.0/Paper' body=None name='Umsetzungsstand der Neuausrichtung der Quartiersarbeit in Freiburg' reference='SO-22/005' date=datetime.datetime(2022, 6, 8, 0, 0) paper_type='INFORMATIONS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/30704' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='zur Information' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2022-SO-190%7C5000405100004%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='3' order=None name='Umsetzungsstand der Neuausrichtung der Quartiersarbeit in Freiburg' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/5000405100004
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-OR_HD-149' type='https://schema.oparl.org/1.0/Meeting' name='6. Sitzung des Ortschaftsrates Hochdorf' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 6, 20, 20, 0) end=datetime.datetime(2022, 6, 20, 22, 30) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/5000405100004' type='https://schema.oparl.org/1.0/Paper' body=None name='Umsetzungsstand der Neuausrichtung der Quartiersarbeit in Freiburg' reference='SO-22/005' date=datetime.datetime(2022, 6, 8, 0, 0) paper_type='INFORMATIONS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/30705' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='Anhörung' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2022-OR_HD-149%7C5000405100004%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='3' order=None name='Umsetzungsstand der Neuausrichtung der Quartiersarbeit in Freiburg' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/4892504100117
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-GR-237' type='https://schema.oparl.org/1.0/Meeting' name='6. Sitzung des Gemeinderates' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 7, 12, 16, 8) end=datetime.datetime(2022, 7, 12, 19, 13) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/4892504100117' type='https://schema.oparl.org/1.0/Paper' body=None name="Bebauungsplan mit örtlichen Bauvorschriften 'Quartier Kleineschholz', Plan-Nr. 5-121 (Stühlinger)\r\na) Beschluss der Änderung der Bezeichnung des Bebauungsplans\r\nb) Beschluss der Änderung des Plangebiets des Bebauungsplans\r\nc) Billigung des Bebauungsplanentwurfs für die förmliche Öffentlichkeits- und Behördenbeteiligung (Offenlage)\r\nd) Beschluss zur Durchführung von Artenschutzmaßnahmen (CEF-Maßnahmen)\r\ne) Beauftragung einer Gesellschafteranweisung an die FWTM zur dauerhaften Flächenbereitstellung für eine planexterne Artenschutzmaßnahme\r\nf) Beschluss zur Umlegung der Kreisstraße K 9859 ab dem Knotenpunkt Sundgauallee / Berliner Allee über die Berliner Allee nach Norden und weiter über die Breisacher Straße und die Straße Zur Unterführung bis zur Bundesstraße B 3 (Bismarckallee / Friedrichstraße)" reference='G-22/116' date=datetime.datetime(2022, 6, 22, 0, 0) paper_type='BESCHLUSS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/30768' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='beschließend' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2022-GR-237%7C4892504100117%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='17' order=None name="Bebauungsplan mit örtlichen Bauvorschriften 'Quartier Kleineschholz', Plan-Nr. 5-121 (Stühlinger)\r\na) Beschluss der Änderung der Bezeichnung des Bebauungsplans\r\nb) Beschluss der Änderung des Plangebiets des Bebauungsplans\r\nc) Billigung des Bebauungsplanentwurfs für die förmliche Öffentlichkeits- und Behördenbeteiligung (Offenlage)\r\nd) Beschluss zur Durchführung von Artenschutzmaßnahmen (CEF-Maßnahmen)\r\ne) Beauftragung einer Gesellschafteranweisung an die FWTM zur dauerhaften Flächenbereitstellung für eine planexterne Artenschutzmaßnahme\r\nf) Beschluss zur Umlegung der Kreisstraße K 9859 ab dem Knotenpunkt Sundgauallee / Berliner Allee über die Berliner Allee nach Norden und weiter über die Breisacher Straße und die Straße Zur Unterführung bis zur Bundesstraße B 3 (Bismarckallee / Friedrichstraße)" public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/4892308100197
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-OR_HD-153' type='https://schema.oparl.org/1.0/Meeting' name='10. Sitzung des Ortschaftsrates Hochdorf' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 11, 7, 20, 0) end=datetime.datetime(2022, 11, 7, 22, 50) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/4892308100197' type='https://schema.oparl.org/1.0/Paper' body=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' reference='G-22/193' date=datetime.datetime(2022, 10, 19, 0, 0) paper_type='INFORMATIONS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/31184' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='zur Information' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2022-OR_HD-153%7C4892308100197%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='8' order=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/4892308100197
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-GR-244' type='https://schema.oparl.org/1.0/Meeting' name='13. Sitzung des Gemeinderates' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 12, 6, 16, 8) end=datetime.datetime(2022, 12, 6, 19, 25) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/4892308100197' type='https://schema.oparl.org/1.0/Paper' body=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' reference='G-22/193' date=datetime.datetime(2022, 10, 19, 0, 0) paper_type='INFORMATIONS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/31182' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='zur Information' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2022-GR-244%7C4892308100197%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='17' order=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/4892308100197
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-OR_EB-72' type='https://schema.oparl.org/1.0/Meeting' name=' 9. Sitzung des Ortschaftsrates Ebnet' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 11, 21, 19, 0) end=datetime.datetime(2022, 11, 21, 21, 0) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/4892308100197' type='https://schema.oparl.org/1.0/Paper' body=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' reference='G-22/193' date=datetime.datetime(2022, 10, 19, 0, 0) paper_type='INFORMATIONS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/31183' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='Anhörung' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2022-OR_EB-72%7C4892308100197%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='5' order=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/4892308100197
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-OR_MU-74' type='https://schema.oparl.org/1.0/Meeting' name='Sitzung des Ortschaftsrates Munzingen' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 11, 30, 19, 30) end=datetime.datetime(2022, 11, 30, 21, 39) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/4892308100197' type='https://schema.oparl.org/1.0/Paper' body=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' reference='G-22/193' date=datetime.datetime(2022, 10, 19, 0, 0) paper_type='INFORMATIONS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/31323' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role=None license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2022-OR_MU-74%7C4892308100197%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='4' order=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/4892308100197
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-MIA-12' type='https://schema.oparl.org/1.0/Meeting' name='Gemeinsame Sitzung des Ausschusses für Migration und Integration und des Sozialausschusses' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 12, 1, 16, 0) end=datetime.datetime(2022, 12, 1, 19, 20) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/4892308100197' type='https://schema.oparl.org/1.0/Paper' body=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' reference='G-22/193' date=datetime.datetime(2022, 10, 19, 0, 0) paper_type='INFORMATIONS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/31193' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='zur Information' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2022-MIA-12%7C4892308100197%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='2' order=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/4892308100197
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-HFA-61' type='https://schema.oparl.org/1.0/Meeting' name='13. Sitzung des Haupt- und Finanzausschusses' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 11, 28, 16, 7) end=datetime.datetime(2022, 11, 28, 18, 0) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/4892308100197' type='https://schema.oparl.org/1.0/Paper' body=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' reference='G-22/193' date=datetime.datetime(2022, 10, 19, 0, 0) paper_type='INFORMATIONS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/31191' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='zur Information' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2022-HFA-61%7C4892308100197%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='12' order=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/4892308100197
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-OR_WA-81' type='https://schema.oparl.org/1.0/Meeting' name='9. Sitzung des Ortschaftsrates Waltershofen' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 11, 22, 20, 0) end=datetime.datetime(2022, 11, 22, 21, 30) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/4892308100197' type='https://schema.oparl.org/1.0/Paper' body=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' reference='G-22/193' date=datetime.datetime(2022, 10, 19, 0, 0) paper_type='INFORMATIONS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/31190' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='Anhörung' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2022-OR_WA-81%7C4892308100197%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='3' order=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/4892308100197
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-OR_OPF-75' type='https://schema.oparl.org/1.0/Meeting' name='9. Sitzung des Ortschaftsrates Opfingen' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 11, 7, 20, 0) end=datetime.datetime(2022, 11, 7, 22, 30) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/4892308100197' type='https://schema.oparl.org/1.0/Paper' body=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' reference='G-22/193' date=datetime.datetime(2022, 10, 19, 0, 0) paper_type='INFORMATIONS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/31188' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='Anhörung' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2022-OR_OPF-75%7C4892308100197%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='6' order=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/4892308100197
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-OR_LE-93' type='https://schema.oparl.org/1.0/Meeting' name='9. Sitzung des Ortschaftsrates Lehen' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 11, 15, 20, 2) end=datetime.datetime(2022, 11, 15, 22, 22) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/4892308100197' type='https://schema.oparl.org/1.0/Paper' body=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' reference='G-22/193' date=datetime.datetime(2022, 10, 19, 0, 0) paper_type='INFORMATIONS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/31186' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='Anhörung' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2022-OR_LE-93%7C4892308100197%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='5' order=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/4892308100197
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2021-OR_TI-94' type='https://schema.oparl.org/1.0/Meeting' name='10. Sitzung des Ortschaftsrates Tiengen' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 11, 29, 20, 0) end=datetime.datetime(2022, 11, 29, 22, 17) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/4892308100197' type='https://schema.oparl.org/1.0/Paper' body=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' reference='G-22/193' date=datetime.datetime(2022, 10, 19, 0, 0) paper_type='INFORMATIONS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/31189' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='Anhörung' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2021-OR_TI-94%7C4892308100197%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='3. b)' order=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/4892308100197
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-MIA-12' type='https://schema.oparl.org/1.0/Meeting' name='Gemeinsame Sitzung des Ausschusses für Migration und Integration und des Sozialausschusses' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 12, 1, 16, 0) end=datetime.datetime(2022, 12, 1, 19, 20) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/4892308100197' type='https://schema.oparl.org/1.0/Paper' body=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' reference='G-22/193' date=datetime.datetime(2022, 10, 19, 0, 0) paper_type='INFORMATIONS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/31192' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='zur Information' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2022-MIA-12%7C4892308100197%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='2' order=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/4892308100197
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-OR_MU-73' type='https://schema.oparl.org/1.0/Meeting' name='Sitzung des Ortschaftsrates Munzingen' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 11, 2, 18, 30) end=datetime.datetime(2022, 11, 2, 20, 0) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/4892308100197' type='https://schema.oparl.org/1.0/Paper' body=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' reference='G-22/193' date=datetime.datetime(2022, 10, 19, 0, 0) paper_type='INFORMATIONS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/31187' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='Anhörung' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2022-OR_MU-73%7C4892308100197%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='5' order=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/4892308100197
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-BaUStA-35' type='https://schema.oparl.org/1.0/Meeting' name='9. Sitzung des Bau-, Umlegungs- und Stadtentwicklungsausschusses' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 10, 26, 16, 3) end=datetime.datetime(2022, 10, 26, 18, 48) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_paper id='https://ris.freiburg.de/oparl/paper/4892308100197' type='https://schema.oparl.org/1.0/Paper' body=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' reference='G-22/193' date=datetime.datetime(2022, 10, 19, 0, 0) paper_type='INFORMATIONS-VORLAGE' related_paper=None superordinated_paper=None subordinated_paper=None main_file=None auxiliary_file=None location=None originator_person=None under_direction_of=None originator_organization=None consultation=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# related_consultation id='https://ris.freiburg.de/oparl/consultation/31181' type='https://schema.oparl.org/1.0/Consultation' paper=None agenda_item=None meeting=None organization=None authoritative=False role='zur Information' license=None keyword=None created=None modified=None web=None deleted=None
# related_agenda_item id='https://ris.freiburg.de/oparl/agendaItem/ni_2022-BaUStA-35%7C4892308100197%7C1' type='https://schema.oparl.org/1.0/AgendaItem' meeting=None number='4' order=None name='Flächennutzungsplan 2040 - Wohnungsmarktanalyse und -bedarfsprognose\r\nErgebnisse der Studie und Handlungsempfehlungen' public=True consultation=None result=None resolution_text=None resolution_file=None auxiliary_file=None start=None end=None license=None keyword=None created=None modified=None web=None deleted=None
# https://ris.freiburg.de/oparl/file/4892308100197
# related_meeting id='https://ris.freiburg.de/oparl/meeting/ni_2022-OR_KA-63' type='https://schema.oparl.org/1.0/Meeting' name='8. Sitzung des Ortschaftsrates Kappel' meeting_state='durchgeführt' cancelled=False start=datetime.datetime(2022, 11, 29, 19, 30) end=datetime.datetime(2022, 11, 29, 21, 4) location=None organization=None participant=None invitation=None results_protocol=None verbatim_protocol=None auxiliary_file=None agenda_item=None license=None keyword=None created=datetime.datetime(2024, 9, 13, 0, 0) modified=datetime.datetime(2024, 9, 13, 0, 0) web=None deleted=False
# ...
# id='89e230e2-c748-42f2-859e-80bfcb764c39' step=<HitStep.DOUBLED: 'DOUBLED'> file_chunk=FileChunk(id='8f5782f8-6d18-4566-807b-e1d765ece4d8', file_section_id=None, text='Der erste Beteiligungstermin fand am 08.12.2022 direkt im Gebiet statt. Dabei ging es neben dem Spielplatz auch um die unmittelbar angrenzende Ballspielfläche. Es wurden die bestehenden Probleme und Defizite beider Flächen ermittelt und die besonderen Qualitäten und Stärken analysiert. Vorschläge für die Neugestaltung konnten sowohl direkt im Termin als auch im anschließend aufgehängten „Wunschbriefkasten“ abgegeben werden.', created_at=datetime.datetime(2024, 9, 8, 23, 55, 21, 860078), modified_at=datetime.datetime(2024, 9, 8, 23, 55, 21, 860079)) file_section=FileSection(id='b39b3f41-26b8-4757-93e3-90ed18c9a70d', file_id=None, text='- 2 -\n2. Geplante Maßnahmen\nDie Neuplanung des Kinderspielplatzes orientiert sich an den bestehenden Flächen und behält die vorhandene Geländemodellierung weitgehend bei. Der prägende Baumbestand sowie der den Spielpatz umgebende Gehölzsaum bleiben erhalten. Ein barrierefreier Weg verbindet künftig die beiden gegenüberliegenden Zugänge aus dem Quartier und zoniert den Spielplatz in einen Bereich für das Bewegungsspiel der älteren Kinder und einen ruhigeren Teil für Kleinkinder.\n\nDer den älteren Kindern zugeordnete Bereich nutzt den bestehenden Rasenhügel für die Anordnung von Kletterspielelementen. Der vorhandene Wiesencharakter soll erhalten bleiben, vorhandene Findlinge werden hier wieder eingebaut, Weidensträucher ergänzen diese naturnahe Spielfläche. Zwei Robinienpfosten können zum Aufhängen einer Hängematte oder auch zum Spannen einer Slackline genutzt werden. Ein Kombinationsspielgerät mit Rutsche, eine Doppelschaukel und ein Drehspiel vervollständigen das Spielangebot.\n\nDer den Kleinkindern zugeordnete Bereich besteht aus einer baumüberstandenen modellierten Rasenfläche und einem Sandbereich mit altersgerechten Spielgeräten zum Klettern und Rutschen. Ein Holzpodest bietet sich als Liegefläche und inklusivem Zugang zum Sandbereich an. Robinienpfosten bieten die Möglichkeit ein Sonnensegel zu spannen. Zentral befindet sich ein inklusiv nutzbarer Wasserspielbereich mit Pumpe.\n\nDie vorhandenen Trampelpfade im umgebenden Gehölzsaum werden behutsam mit kleinen Balancierelementen und farbigen Aufmerksamkeitspunkten ergänzt und die Spielfläche damit bewusst in diese Ränder erweitert. An verschiedenen Stellen des Spielplatzes bieten sich Bänke zum Aufenthalt an. Der vorhandene Zaun bleibt weitgehend bestehen und wird nur an die veränderte Zugangssituationen angepasst, ein Durchgang zur angrenzenden Ballspielfläche wird neu geschaffen. Die Pflegezufahrt erfolgt künftig von der Erschließungsstraße im Südosten des Spielplatzes.\n\nDie geplanten Maßnahmen sind in der Vorentwurfsplanung graphisch dargestellt, diese ist der vorliegenden Drucksache als Anlage 3 beigefügt.\n\nAnlage 2 zur DRUCKSACHE G-24/040\nMaßnahmenbeschreibung\n\n1. Beteiligungsverfahren\nIm Rahmen der Planung zur Umgestaltung des Kinderspielplatzes im Breisacher Hof wurde ein umfangreiches, zweistufiges Beteiligungsverfahren durchgeführt. Neben den Kindern, Familien und Anwohnern des Quartiers und der benachbarten Gegend wurden auch Vertreter_innen der umliegenden Kindergärten, des Sozial- und Jugendzentrums Breisacher Hof sowie des Bürgervereins Mooswald und der Quartiersarbeit Mooswald eingeladen.\n\nDer erste Beteiligungstermin fand am 08.12.2022 direkt im Gebiet statt. Dabei ging es neben dem Spielplatz auch um die unmittelbar angrenzende Ballspielfläche. Es wurden die bestehenden Probleme und Defizite beider Flächen ermittelt und die besonderen Qualitäten und Stärken analysiert. Vorschläge für die Neugestaltung konnten sowohl direkt im Termin als auch im anschließend aufgehängten „Wunschbriefkasten“ abgegeben werden.\n\nDie vielen Ideen und Anregungen wurden von der Verwaltung gemeinsam mit dem beauftragten Planungsbüro ausgewertet. Auf dieser Basis konnte  ...
# id='d04fb247-88ae-4011-93c6-7c0fb16c7f34' step=<HitStep.RELATED_DATA_GATHERED: 'RELATED_DATA_GATHERED'> file_chunk=FileChunk(id='dbc2ecf6-ef77-4be4-bef6-f7c2058ae387', file_section_id=None, text='Abgrenzung mit Hinweise auf den Zeitdruck wegen eben dieser Offenlage. Die Erschließung laufe über den nördlichen Teil der St- Erentrudis-Straße; vier größere Baukörper seien vorgesehen, 4 Reihenhäuser in Eigentum und kleinere Innenhöfe sowie Freiräume. Das Herzstück sei der Quartiersplatz mit Kinderspielplätzen und Beeten zum gemeinsamen Gärtnern; direkt anschließend das Quartiersbüro, sowie genügend Stellplätze, um Wildparken zu verhindern, da man hier mehr oder weniger aufs Auto angewiesen', created_at=datetime.datetime(2024, 9, 8, 19, 14, 17, 478863), modified_at=datetime.datetime(2024, 9, 8, 19, 14, 17, 478864)) file_section=FileSection(id='f6e98a07-92e4-4df4-aad0-ed6d1d40e218', file_id=None, text='\n6\n\nAbgrenzung mit Hinweise auf den Zeitdruck wegen eben dieser Offenlage. Die Erschließung laufe über den nördlichen Teil der St- Erentrudis-Straße; vier größere Baukörper seien vorgesehen, 4 Reihenhäuser in Eigentum und kleinere Innenhöfe sowie Freiräume. Das Herzstück sei der Quartiersplatz mit Kinderspielplätzen und Beeten zum gemeinsamen Gärtnern; direkt anschließend das Quartiersbüro, sowie genügend Stellplätze, um Wildparken zu verhindern, da man hier mehr oder weniger aufs Auto angewiesen sei. Man könne hier nicht unterkellern, d.h. man müsse die Nebenanlagen als Ersatzräumlichkeiten unterkriegen sowie Fahrräder etc. Es entstünden ca. 44 Wohneinheiten (WE), davon geförderter, als auch freifinanzierter Wohnungsbau und Eigentum. Für die Entwässerung müsse ein Gefälle hergestellt werden, um das Wasser dahin zu bekommen wo man es benötige; die Erschließung solle nördlich über die St.-Erentrudis-Straße erfolgen. Die entsprechende rosa Markierung sei ein Biotopstreifen; dort liege der Abwasserkanal des Abwasserzweckverbandes; wenn möglich solle dieser in den ‘Alten Weg1 verlegt werden. Für bebaute Bereiche sei der Eigenbetrieb Stadtentwässerung zuständig. Daraufhin erläuterte Frau Trautmann den Schnitt des Plangebietes (siehe PowerPoint Präsentation)3 Vollgeschosse mit Flachdach. Das Jugendhaus sei einen Steinwurf vom Roßbächle entfernt; nun müsse man schauen, wie man den Kita-Bedarf gedeckt bekomme? Man sei hier noch am Anfang der Planung; der Aufstellungsbeschluss aber schon gefasst; der Flächenbedarf für die Kita sei vorgegeben worden; der Bolzplatz aktuell überdimensioniert. Nun müsse man als erstes ein Lärmgutachten in Auftrag geben, da z.B. die Schlafplätze der Kita nicht neben dem Bolzplatz angebracht werden dürften, aufgrund des besonderen Ruhebedarfes dieser Altersgruppe. Der Lärmgutachter gebe an, wie die Gebäude angeordnet werden könnten. Der Zeitplan würde vorsehen, dass Planunterlagen offengelegt werden; Unterlagen für den Satzungsbeschluss würden dann bearbeitet werden.\n\nWortmeldungen:\nORätin Stifel gab zu bedenken, dass der Verkehr ist an dieser Stelle sehr schnell sei und wollte wissen, ob es Überlegungen, gebe, wie man zu Fuß zur Kita komme, ohne das Auto nehmen zu müssen? Frau Trautmann stellte heraus, dass es eine Lücke zu den Tennisplätzen gäbe und ein Verkehrsgutachten erstellt werde, das erarbeite, wie man fußläufig zu der Kita kommen könne.\n\nProtokoll der OR-Sitzung vom 12.05.2021\n\n7\n\nORätin Weber befand, dass ein Innenhof nicht gerade förderlich für die Integration der Menschen sei, da diese so unter sich bleiben und hielt es für den Ort für wichtig, dass alle neu Hinzuziehenden miteinander lebten. Frau Trautmann erwähnte, dass man im Baugenehmigungsverfahren übers Roßbächle eine kleine Fußgängerbrücke anbringen wolle, als sog. 2. Anbindung im Süden für Fußgänger und Radfahrer.\n\nHerr Freyler fügte an, dass die Wohnstruktur dazu beitragen solle, dass Menschen sich sozial durchmischen. Vor Ort sei dann ein Hausmeister ansprechbar für alle Personen in diesem Gebiet. Frau Trautmann befand, dass dies  ...
# id='e350961d-6339-4db2-9312-355455906a5c' step=<HitStep.DOUBLED: 'DOUBLED'> file_chunk=FileChunk(id='f568acd5-71dd-4956-a5dd-6c347912d25d', file_section_id=None, text='1) Information über den Haushalt sowie Öffentlichkeitsarbeit für die aktive Teilnahme am Beteiligungsverfahren\n2) Beteiligung: Bürger_innen werden konsultiert und erhalten die Möglichkeit, ihre eigenen Ideen und Prioritäten einzubringen. In der Rolle von Beratenden adressieren sie ihre Vorschläge an Politik und Verwaltung. Ein weiteres Element ist der öffentliche Diskurs, zum Beispiel bei Versammlungen oder über ein Online-Forum.', created_at=datetime.datetime(2024, 9, 9, 4, 18, 57, 185956), modified_at=datetime.datetime(2024, 9, 9, 4, 18, 57, 185957)) file_section=FileSection(id='d8b71126-7b19-4856-88bc-c721e13040c0', file_id=None, text='2\n\nBETEILIGUNGSHAUSHALT 2023/24   Abschlussbericht  \nFreiburg IM BREISGAU\n\nINHALTSVERZEICHNIS\n\n1 EINLEITUNG ........................................................................................................................................ 5\n2 KONZEPT ............................................................................................................................................. 5\n    2.1 ANALOGE UND DIGITALE INFORMATIONSKAMPAGNE ........................................................................... 6\n    2.2 BETEILIGUNGSFORMATE ................................................................................................................... 6\n    2.3 RECHENSCHAFT ZUM VERFAHREN UND DEN ERGEBNISSEN .................................................................. 6\n3 ERGEBNISSE DES BETEILIGUNGSHAUSHALT 2023/24 ............................................................... 11\n    3.1 ANALOGE UND DIGITALE INFORMATIONSKAMPAGNE ......................................................................... 11\n    3.2 BETEILIGUNGSFORMATE .................................................................................................................. 11\n    3.3 RECHENSCHAFT ZUM VERFAHREN UND DEN ERGEBNISSEN .............................................................. 16\n4 EVALUATION DES VERFAHRENS ............................... FEHLER! TEXTMARKE NICHT DEFINIERT.\n5 AUSBLICK/FAZIT ............................................................................................................................... 18\n\n4\n\nAbschlussbericht Beteiligungshaushalt 2023/24\n\nHerausgeberin\nStadt Freiburg im Breisgau\nRathausplatz 2-4\n79098 Freiburg\n\nProjektleitung\nDr. Birte Gundelach, Eva Bengert\nDezernat III, Büro des Ersten Bürgermeisters, Fachbereich Soziale Stadtentwicklung\n\nFreiburg-Umfrage\nAndreas Kern\nAmt für Bürgerservice und Informationsmanagement\n\nGestaltung, Redaktion, technische Realisierung und Moderation der Online-Plattform\nEva Bengert, Christof Heim, Tabea Krauß, Jürgen Smola, Katharina Ziegler\nOnline-Redaktion in Zusammenarbeit mit der polidia GmbH, Berlin\n\nProjektgruppe Beteiligungshaushalt 2023/24\nSusanne Assfalg, Nachhaltigkeitsmanagement\nEva Bengert, Koordinationsstelle Bürgerschaftliches Engagement\nEberhard Heusel, Amtsblatt\nTabea Krauß, Online-Redaktion\nAndreas Kern, Amt für Bürgerservice und Informationsmanagement\nDr. Birte Gundelach, Fachbereich Soziale Stadtentwicklung\nSarah Maier, Stadtkämmerei\nKarin Müller, Stadtkämmerei\nGerhard Rieger, Koordinationsstelle Bürgerschaftliches Engagement\nStella Schewe, Amtsblatt\nMartina Schickle, Pressereferat\nJürgen Smola, Online-Redaktion\nKatharina Ziegler, Online-Redaktion\n\nAbschlussbericht\nText und Redaktion: Fachbereich Soziale Stadtentwicklung mit Unterstützung der Projektgruppe Beteiligungshaushalt\nTitel: Plakatmotiv der Werbekampagne zum Beteiligungshaushalt, Grafikdesign Sommer\n\n3\n\n1 Einleitung\nSeit den Beratungen zum Doppelhaushalt 2009/10 bietet die Stadt den Bürger_innen im Rahmen des Beteiligungshaushaltes (BHH) die Möglichkeit, sich über den städtischen Haushalt umfangreich zu informieren und dess ...
# Error running evaluator <DynamicRunEvaluator answer_evaluator> on run 3f8ba053-f785-43bb-b1a9-080b91a70546: KeyError('answer')
# Traceback (most recent call last):
#   File "/Users/pascal/neurapolis/evals/retriever/.venv/lib/python3.12/site-packages/langsmith/evaluation/_runner.py", line 1344, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/retriever/.venv/lib/python3.12/site-packages/langsmith/evaluation/evaluator.py", line 327, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/Users/pascal/neurapolis/evals/retriever/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 646, in wrapper
#     raise e
#   File "/Users/pascal/neurapolis/evals/retriever/.venv/lib/python3.12/site-packages/langsmith/run_helpers.py", line 643, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/_x/18_1sczx5634lnky__ljb3900000gn/T/ipykernel_62622/23886704.py", line 17, in answer_evaluator
#     reference = example.outputs["answer"]
#                 ~~~~~~~~~~~~~~~^^^^^^^^^^
# KeyError: 'answer'
# 1it [00:14, 14.12s/it]
